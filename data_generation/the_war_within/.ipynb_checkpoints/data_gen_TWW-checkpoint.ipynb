# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import warnings
import re
import joblib
import string
import os

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %%
DATA_DIR = './data/'
STATIC_DIR = '../../static/data/'

# %% [markdown]
# # Functions and Classes

# %%
def getSpecializations(profession):
    prof_data = dict()
    
    stats = ['skill', 'multicraft', 'resourcefulness', 'ingenuity']
    for stat in stats:
        prof_data[stat] = dict()
        with open(DATA_DIR+profession.lower()+'_specializations_'+stat+'.csv', 'r') as file:
            data = file.readlines()[1:]
            for line in data:
                line = line.strip().split(',')
                node = line[0]
                maxPoints = int(line[1])
                gainPerPoint = int(line[2])
                gains = line[3:][:maxPoints//5+1]
                gains = [int(x) for x in gains]
                    
                prof_data[stat][node] = dict(zip(np.arange(start=0, stop=maxPoints+1, step=5), gains))
                prof_data[stat][node]['scaling'] = gainPerPoint
                
    return prof_data

# %%
def getItems(profession):
    prof_items = dict()
    
    with open(DATA_DIR+profession+'_specializations_items.csv', 'r') as file:
        data = file.readlines()[1:]
        
        for line in data:
            line = line.strip().split(',')
            itemID = int(line[0])
            itemName = line[1]
            
            lastIndex = len(np.where(np.array(line)!='')[0])
            nodes = line[2:lastIndex]
            
            prof_items[itemID] = dict()
            prof_items[itemID]['itemName'] = itemName
            prof_items[itemID]['nodes'] = nodes
            
    return prof_items

# %%
def scrapeIcon(itemID):
    url = f'https://www.wowhead.com/item={itemID}'
    soup = BeautifulSoup(requests.get(url).text) 
    
    #wowhead no longer has this href so need to us another method
    #link = soup.find(name='link', attrs={'rel':'image_src'})['href'] 
    
    #if link.find('http') < 0:
    #    icon_links.append(None)
    #    continue
    #    
    #first = link.find('http', 1)
    #second = link.find('http', 2)
    #if second >= first:
    #    icon_links.append(link[second:])
    #else:
    #    assert('what')
    
    #new method using regex
    
    #string1 finds strings preceded by:   "{itemID}:{" 
    #and are also followed by:    ,"screenshot"
    #the strings cannot include the symbol:   }
    string1 = re.search(r'(?<="'+f'{itemID}'+r'":{)[^}]+(?=,"screenshot")', str(soup)).group()
    
    #string2 searches string1 for strings preceded by:      "icon":"
    #and are also followed by:      ")
    #that only contain a-z, A-Z, 0-9, _, and -
    string2 = re.search(r'(?<="icon":")[\w-]+(?=")', string1).group()
    site = 'https://wow.zamimg.com/images/wow/icons/large/'+string2+'.jpg'
    
    status_code = requests.get(site).status_code
    
    if status_code==200:
        return {itemID: site}
    else:
        return {itemID: None}

# %%
def check_id(old_id):
    url = f'https://www.wowhead.com/item={old_id}?xml'
    html = requests.get(url).text
    soup = BeautifulSoup(html, features='xml')
    name = soup.find('name').text
    text = soup.find('htmlTooltip').text
    
    #check for quality tier information
    if text.find('quality-tier1') >= 0:
        new_id = old_id+2
        new_id_lower = old_id-2
    elif text.find('quality-tier2') >= 0:
        new_id = old_id+1
        new_id_lower = old_id-1
    else: #either its tier3 or it doesn't have tiers, in which use the old_id
        return {old_id: old_id}
    
    
    #wasn't a tier 3 item, so check the calculated id for if the name matches and is tier 3
    #return the new id if it is the same name and tier 3, else return -1 for manual checking
    try:
        url = f'https://www.wowhead.com/item={new_id}?xml'
        html = requests.get(url).text
        soup = BeautifulSoup(html, features='xml')
        if soup.find('name').text == name and soup.find('htmlTooltip').text.find('quality-tier3') >= 0:
            return {old_id: new_id}
    except:
        pass
    
    try:
        url = f'https://www.wowhead.com/item={new_id_lower}?xml'
        html = requests.get(url).text
        soup = BeautifulSoup(html, features='xml')
        if soup.find('name').text == name and soup.find('htmlTooltip').text.find('quality-tier3') >= 0:
            return {old_id: new_id_lower}
    except:
        return {old_id: -1}
        
    return {old_id: -1}

# %%
def outcomeQuality(skill, difficulty, tag):
    if tag.lower()[:4]=='gear':
        arr = np.array([1, 0.2*difficulty, 0.5*difficulty, 0.8*difficulty, difficulty])
    else:
        arr = np.array([1, 0.5*difficulty, difficulty])
        
    return (skill >= arr).sum()

# %%
def getProfession(file, name):
    #### deprecated version ###
    prof = Profession(name)
    
    with open(file, 'r', encoding='utf-8-sig') as file:
        data = file.readlines()
        
    reagentStart = 14 #column number where reagents start, since the variable counts dont work with headers
    headers = data[0].strip().split(',')[:reagentStart] #no headers for reagents
    for line in data[1:]:
        itemInfo = line.strip().split(',')

        try:
            #take first index where an empty string occurs to indicate where input values stop
            reagentEnd = np.where(np.array(itemInfo)=='')[0].min()
        except:
            #no value existed -> all indices are used -> use None for slicing
            reagentEnd = None

        reagents = itemInfo[reagentStart:reagentEnd]
        reagents = np.array(reagents).astype(int)

        itemInfo = dict(zip(headers, itemInfo[:reagentStart]))
        reagents = dict(zip(reagents[::2], reagents[1::2]))

        #can't call float('np.nan'), so replace the string with value manually
        for k,v in itemInfo.items():
            if v == 'np.nan':
                itemInfo[k] = np.nan
                
        prof.add(itemName = itemInfo.get('itemName'),
                 itemID = itemInfo.get('itemID'),
                 reagents = reagents,
                 crafterName = itemInfo.get('crafterName'),
                 tag = itemInfo.get('tag'),
                 difficulty = itemInfo.get('difficulty'),
                 multicraft = itemInfo.get('multicraft'),
                 quantity = itemInfo.get('quantity'),
                 skill = itemInfo.get('skill'),
                 rarity = itemInfo.get('rarity'),
                 hasReagentQualities = (itemInfo.get('hasReagentQualities').title()=='True'),
                 hasEmbellishmentSlot = (itemInfo.get('hasEmbellishmentSlot').title()=='True'),
                 hasMissiveSlot = (itemInfo.get('hasMissiveSlot').title()=='True'),
                 hasSafetyComponent = (itemInfo.get('hasSafetyComponent').title()=='True'),
                 hasCrestSlot = (itemInfo.get('hasCrestSlot').title()=='True'))
        
    return prof

# %%
def getProfession(file, name):
    prof = Profession(name)
    
    baseFile = file[len(DATA_DIR):-4]
    if baseFile[-1] in string.digits:
        num = baseFile[-1]
        baseFile = baseFile[:-1]
    else:
        num = ''
    
    with open(file, 'r', encoding='utf-8-sig') as file:
        data = file.readlines()
        
    reagentStart = 14 #column number where reagents start, since the variable counts dont work with headers
    headers = data[0].strip().split(',')[:reagentStart] #no headers for reagents
    for line in data[1:]:
        itemInfo = line.strip().split(',')

        try:
            #take first index where an empty string occurs to indicate where input values stop
            reagentEnd = np.where(np.array(itemInfo)=='')[0].min()
        except:
            #no value existed -> all indices are used -> use None for slicing
            reagentEnd = None

        reagents = itemInfo[reagentStart:reagentEnd]
        reagents = np.array(reagents).astype(int)

        itemInfo = dict(zip(headers, itemInfo[:reagentStart]))
        reagents = dict(zip(reagents[::2], reagents[1::2]))

        #can't call float('np.nan'), so replace the string with value manually
        for k,v in itemInfo.items():
            if v == 'np.nan':
                itemInfo[k] = np.nan
                
        itemID = int(itemInfo.get('itemID'))
        
        skill = float(itemInfo.get('skill'))
        skill += float(baseStats.loc[baseStats['profession']==baseFile+num, 'level'].iloc[0])
        skill += float(baseStats.loc[baseStats['profession']==baseFile+num, 'skill'].iloc[0])
        
        multicraft = float(itemInfo.get('multicraft'))
        multicraft += float(baseStats.loc[baseStats['profession']==baseFile+num, 'multicraft'].iloc[0])
        
        if name.lower() != 'cooking':   
            specializationInfo = getSpecializations(name.lower())
            specializationItems = getItems(name.lower())
            knowledgePoints = pd.read_csv(DATA_DIR+baseFile+'_knowledge'+num+'.csv')
            
            skill += getStat(specializationInfo['skill'], knowledgePoints, specializationItems[itemID]['nodes'])
            multicraft += getStat(specializationInfo['multicraft'], knowledgePoints, 
                                  specializationItems[itemID]['nodes'])
            
        multicraft = np.round(multicraft/33, 1) #convert from stat to percent
                
        prof.add(itemName = itemInfo.get('itemName'),
                 itemID = itemID,
                 reagents = reagents,
                 crafterName = itemInfo.get('crafterName'),
                 tag = itemInfo.get('tag'),
                 difficulty = itemInfo.get('difficulty'),
                 multicraft = multicraft,
                 quantity = itemInfo.get('quantity'),
                 skill = skill,
                 rarity = itemInfo.get('rarity'),
                 hasReagentQualities = (itemInfo.get('hasReagentQualities').title()=='True'),
                 hasEmbellishmentSlot = (itemInfo.get('hasEmbellishmentSlot').title()=='True'),
                 hasMissiveSlot = (itemInfo.get('hasMissiveSlot').title()=='True'),
                 hasSafetyComponent = (itemInfo.get('hasSafetyComponent').title()=='True'),
                 hasCrestSlot = (itemInfo.get('hasCrestSlot').title()=='True'))
        
    return prof

# %%
def getStat(nodeValues, knowledgePoints, nodes):    
    statValue = 0
    
    for node in nodes:
        try:
            
            knowledge = knowledgePoints.loc[knowledgePoints['node']==node, 'points'].iloc[0]
        except:
            print(node)
            display(nodeValues)
            display(knowledgePoints)
            display(knowledgePoints.loc[knowledgePoints['node']==node, :])
            assert False
        # skip if node not unlocked
        if knowledge == -1:
            continue
        
        breakpoints = np.arange(start=0, stop=knowledge+1, step=5)
        for breakpoint in breakpoints:
            try:
                statValue += nodeValues[node][breakpoint]
            except:
                display(node)
                display(breakpoint)
                display(nodeValues)
                display(knowledgePoints)
                assert False
        statValue += nodeValues[node]['scaling']*knowledge
        
    return statValue

# %%
def updateReagents(reagents: dict, replacementIDs: dict):
    return {replacementIDs.get(reagent, reagent):count for reagent,count in reagents.items()}

# %%
class Profession:
    __all_data = None
    __name = None
    
    def __init__(self, profession):
        self.__all_data = list()
        self.__name = profession
        
    def add(self, itemName, itemID, reagents, crafterName, tag, difficulty, multicraft, quantity, skill,
            rarity, hasReagentQualities, hasEmbellishmentSlot, hasMissiveSlot, hasSafetyComponent, hasCrestSlot):

            self.__all_data.append([self.__name, crafterName, itemID, itemName, None, reagents, tag, rarity, 
                                    difficulty, skill, quantity, multicraft, hasReagentQualities, 
                                    hasEmbellishmentSlot, hasMissiveSlot, hasSafetyComponent, hasCrestSlot])
            
    def get_table(self):
        columns = ['profession', 'character', 'itemID', 'item', 'icon', 'reagents', 'tag', 'rarity', 
                   'difficulty', 'skill1', 'baseQuantity', 'multicraftPercent', 'hasReagentQualities', 
                   'hasEmbellishmentSlot', 'hasMissiveSlot', 'hasSafetyComponent', 'hasCrestSlot']
        dtypes = ['string', 'string', 'int32', 'string', 'string', 'object', 'string', 'string', float, float, 
                  'string', float, bool, bool, bool, bool, bool, bool]
        df = pd.DataFrame(columns=columns, data=self.__all_data)
        return df.astype(dict(zip(columns, dtypes)))
        
    def set_table(self, df):
        self.__all_data = df.to_numpy()

# %% [markdown]
# # Initial DataFrames

# %%
items_columns = ['itemID', 'item', 'icon', 'tag', 'rarity']
items_dtypes = ['int32', 'string', 'string', 'string', 'string']
items = pd.DataFrame(columns=items_columns)

professions_columns = ['profession', 'itemID', 'reagents', 'hasReagentQualities', 'hasEmbellishmentSlot',
                       'hasMissiveSlot', 'hasSafetyComponent', 'hasCrestSlot']
professions_dtypes = ['string', 'int32', dict, bool, bool, bool, bool, bool]
professions = pd.DataFrame(columns=professions_columns)

crafting_columns = ['itemID', 'difficulty', 'character', 'skill1', 'base_quantity', 'multicraft_percent']
crafting_dtypes = ['int32', 'int16', 'string', float, 'string', float]
crafting = pd.DataFrame(columns=crafting_columns)

# %%
baseStats = pd.read_csv(DATA_DIR+'base_stats.csv')

# %%
alchemy = getProfession(DATA_DIR+'alchemy.csv', 'Alchemy')
alchemy2 = getProfession(DATA_DIR+'alchemy2.csv', 'Alchemy')
blacksmithing = getProfession(DATA_DIR+'blacksmithing.csv', 'Blacksmithing')
blacksmithing2 = getProfession(DATA_DIR+'blacksmithing2.csv', 'Blacksmithing')
cooking = getProfession(DATA_DIR+'cooking.csv', 'Cooking')
enchanting = getProfession(DATA_DIR+'enchanting.csv', 'Enchanting')
enchanting2 = getProfession(DATA_DIR+'enchanting2.csv', 'Enchanting')
engineering = getProfession(DATA_DIR+'engineering.csv', 'Engineering')
inscription = getProfession(DATA_DIR+'inscription.csv', 'Inscription')
inscription2 = getProfession(DATA_DIR+'inscription2.csv', 'Inscription')
jewelcrafting = getProfession(DATA_DIR+'jewelcrafting.csv', 'Jewelcrafting')
jewelcrafting2 = getProfession(DATA_DIR+'jewelcrafting2.csv', 'Jewelcrafting')
leatherworking = getProfession(DATA_DIR+'leatherworking.csv', 'Leatherworking')
leatherworking2 = getProfession(DATA_DIR+'leatherworking2.csv', 'Leatherworking')
tailoring = getProfession(DATA_DIR+'tailoring.csv', 'Tailoring')
tailoring2 = getProfession(DATA_DIR+'tailoring2.csv', 'Tailoring')

# %% [markdown]
# # DataFrame Merging

# %%
#concatenate tables
#sort by itemID and skill (descending) so items are paired with higher skill on top
#keep the first entry for each itemID (i.e., the highest skill entry)
#break same skill tie by sorting by name such that primary crafter is at the top
sortCols = ['itemID', 'skill1', 'character']
sortVals = [True, False]
nameAscending = {'alchemy': False,
                 'blacksmithing': False,
                 'enchanting': True,
                 'inscription': False,
                 'jewelcrafting': True,
                 'leatherworking': True,
                 'tailoring': False}

all_data = pd.DataFrame()
for df1, df2, name in [(alchemy, alchemy2, 'alchemy'), (blacksmithing, blacksmithing2, 'blacksmithing'),
                       (enchanting, enchanting2, 'enchanting'), (inscription, inscription2, 'inscription'),
                       (jewelcrafting, jewelcrafting2, 'jewelcrafting'), 
                       (leatherworking, leatherworking2, 'leatherworking'), (tailoring, tailoring2, 'tailoring')]:
    df = pd.concat((df1.get_table(), df2.get_table()), ignore_index=True)
    df = df.sort_values(by=['itemID', 'skill1', 'character'], ascending=[True, False]+[nameAscending[name]])
    df = df.groupby('itemID', as_index=False).head(1)
    all_data = pd.concat((all_data, df), ignore_index=True)

# %%
all_data = pd.concat((all_data, cooking.get_table()), ignore_index=True)
all_data = pd.concat((all_data, engineering.get_table()), ignore_index=True)
all_data = all_data.reset_index(drop=True)

# %% [markdown]
# # Manual Adjustments

# %%
fixes = {'"Magically ""Infinite"" Messenger"': 'Magically "Infinite" Messenger'}
all_data['item'] = all_data['item'].apply(lambda x: fixes.get(x, x))

# %% [markdown]
# # Items DataFrame

# %%
#single dataframe of all items, including those listed in reagents
columns = ['itemID', 'item', 'icon']
items = all_data.loc[:, ['itemID', 'item', 'icon']]
items = items.drop_duplicates()
        
for index, row in tqdm(all_data.iterrows(), total=len(all_data)):
    for reagent in row['reagents'].keys():
        if reagent not in items.loc[:, 'itemID'].to_numpy():
            url = f'https://www.wowhead.com/item={reagent}?xml'
            html = requests.get(url).text
            soup = BeautifulSoup(html, features='xml')
            name = soup.find('name').text
            df = pd.DataFrame(columns=columns, data=[[reagent, name, None]])
            items = pd.concat((items, df))
# Out:
# 100%|██████████| 608/608 [00:50<00:00, 12.09it/s]

# %% [markdown]
# # Item Icons

# %%
method = "LOAD"
icon_file = STATIC_DIR+'icons.pkl'

if not os.path.isfile(icon_file) or method == "UPDATE":
    num_cores = joblib.cpu_count()
    all_jobs = [joblib.delayed(scrapeIcon)(itemID) for itemID in items['itemID'].values]
    results = joblib.Parallel(n_jobs=num_cores, verbose=10)(all_jobs)
    icon_links = {int(k):v for d in results for k,v in d.items()}
    icons_df = pd.DataFrame()
    icons_df['itemID'] = icon_links.keys()
    icons_df['link'] = icon_links.values()
    icons_df.to_pickle(icon_file)
elif os.path.isfile(icon_file) and method == "LOAD":
    icon_links = pd.read_pickle(icon_file)
    icon_links = dict(zip(icon_links['itemID'].values, icon_links['link']))

# %%
#update icons in dataframes
all_data['icon'] = all_data['itemID'].map(icon_links)
items['icon'] = items['itemID'].map(icon_links)

# %%
#ensure all items have icons
df = all_data.loc[all_data['icon'].isna(), ['itemID', 'icon']]
assert(len(df)==0)

# %%
icon_links
# Out:
# {210816: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_alchemy_alchemystone_color4.jpg',
#  211802: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_legion_gooamberpink_multi.jpg',
#  211803: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_legion_goooil_multi.jpg',
#  211804: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_legion_gooslime_multi.jpg',
#  211878: 'https://wow.zamimg.com/images/wow/icons/large/inv_flask_red.jpg',
#  212239: 'https://wow.zamimg.com/images/wow/icons/large/inv_flask_blue.jpg',
#  212242: 'https://wow.zamimg.com/images/wow/icons/large/inv_alchemy_elixir_06.jpg',
#  212245: 'https://wow.zamimg.com/images/wow/icons/large/inv_flask_green.jpg',
#  212248: 'https://wow.zamimg.com/images/wow/icons/large/inv_potion_139.jpg',
#  212251: 'https://wow.zamimg.com/images/wow/icons/large/inv_potion_62.jpg',
#  212254: 'https://wow.zamimg.com/images/wow/icons/large/inv_summerfest_firepotion.jpg',
#  212257: 'https://wow.zamimg.com/images/wow/icons/large/inv_potion_16.jpg',
#  212260: 'https://wow.zamimg.com/images/wow/icons/large/inv_alchemy_potion_empty.jpg',
#  212263: 'https://wow.zamimg.com/images/wow/icons/large/trade_alchemy_potiona4.jpg',
#  212266: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_potionseta.jpg',
#  212269: 'https://wow.zamimg.com/images/wow/icons/large/inv_potion_red.jpg',
#  212272: 'https://wow.zamimg.com/images/wow/icons/large/inv_potion_green.jpg',
#  212275: 'https://wow.zamimg.com/images/wow/icons/large/inv_potion_blue.jpg',
#  212278: 'https://wow.zamimg.com/images/wow/icons/large/inv_potion_purlple.jpg',
#  212281: 'https://wow.zamimg.com/images/wow/icons/large/inv_potion_orange.jpg',
#  212289: 'https://wow.zamimg.com/images/wow/icons/large/inv_potionf_5.jpg',
#  212292: 'https://wow.zamimg.com/images/wow/icons/large/inv_potionf_4.jpg',
#  212298: 'https://wow.zamimg.com/images/wow/icons/large/inv_potionf_1.jpg',
#  212299: 'https://wow.zamimg.com/images/wow/icons/large/trade_alchemy_potione4.jpg',
#  212305: 'https://wow.zamimg.com/images/wow/icons/large/inv_potion_163.jpg',
#  212308: 'https://wow.zamimg.com/images/wow/icons/large/inv_potion_162.jpg',
#  212311: 'https://wow.zamimg.com/images/wow/icons/large/inv_potion_160.jpg',
#  212314: 'https://wow.zamimg.com/images/wow/icons/large/inv_potion_165.jpg',
#  212514: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_uncut-epic-gem_color2.jpg',
#  212563: 'https://wow.zamimg.com/images/wow/icons/large/spell_shaman_giftearthmother.jpg',
#  212719: 'https://wow.zamimg.com/images/wow/icons/large/inv_11_alchemy_profession_cauldron04.jpg',
#  212751: 'https://wow.zamimg.com/images/wow/icons/large/inv_11_alchemy_profession_cauldron01.jpg',
#  223883: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_legion_goooil_chunk.jpg',
#  223884: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_legion_gooslime_chunk.jpg',
#  223885: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_legion_goowine_chunk.jpg',
#  223886: 'https://wow.zamimg.com/images/wow/icons/large/inv_-misc_herb_deathblossom_leaf.jpg',
#  223887: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_herb_talandrasrose_petal.jpg',
#  225677: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_legion_gooamberblue_chunk.jpg',
#  228401: 'https://wow.zamimg.com/images/wow/icons/large/inv_potion_159.jpg',
#  228404: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_herb_purplelotus_petal.jpg',
#  217143: 'https://wow.zamimg.com/images/wow/icons/large/inv_chest_plate_undergroundquest_b_01.jpg',
#  217144: 'https://wow.zamimg.com/images/wow/icons/large/inv_boot_plate_undergroundquest_b_01.jpg',
#  217145: 'https://wow.zamimg.com/images/wow/icons/large/inv_glove_plate_undergroundquest_b_01.jpg',
#  217146: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_plate_undergroundquest_b_01.jpg',
#  217147: 'https://wow.zamimg.com/images/wow/icons/large/inv_pant_plate_undergroundquest_b_01.jpg',
#  217148: 'https://wow.zamimg.com/images/wow/icons/large/inv_shoulder_plate_undergroundquest_b_01.jpg',
#  217149: 'https://wow.zamimg.com/images/wow/icons/large/inv_belt_plate_undergroundquest_b_01.jpg',
#  217150: 'https://wow.zamimg.com/images/wow/icons/large/inv_bracer_plate_undergroundquest_b_01.jpg',
#  222417: 'https://wow.zamimg.com/images/wow/icons/large/inv_blacksmithingalloys_green.jpg',
#  222420: 'https://wow.zamimg.com/images/wow/icons/large/inv_blacksmithingalloys_purlple.jpg',
#  222423: 'https://wow.zamimg.com/images/wow/icons/large/inv_blacksmithingalloys_red.jpg',
#  222426: 'https://wow.zamimg.com/images/wow/icons/large/inv_blacksmithingalloys_blue.jpg',
#  222429: 'https://wow.zamimg.com/images/wow/icons/large/inv_plate_outdoorarathor_d_01_boot.jpg',
#  222430: 'https://wow.zamimg.com/images/wow/icons/large/inv_plate_outdoorarathor_d_01_robe.jpg',
#  222431: 'https://wow.zamimg.com/images/wow/icons/large/inv_plate_outdoorarathor_d_01_belt.jpg',
#  222432: 'https://wow.zamimg.com/images/wow/icons/large/inv_shield_1h_arathoroutdoor_d_01.jpg',
#  222433: 'https://wow.zamimg.com/images/wow/icons/large/inv_plate_outdoorarathor_d_01_helm.jpg',
#  222434: 'https://wow.zamimg.com/images/wow/icons/large/inv_plate_outdoorarathor_d_01_pant.jpg',
#  222435: 'https://wow.zamimg.com/images/wow/icons/large/inv_plate_outdoorarathor_d_01_bracer.jpg',
#  222436: 'https://wow.zamimg.com/images/wow/icons/large/inv_plate_outdoorarathor_d_01_shoulder.jpg',
#  222437: 'https://wow.zamimg.com/images/wow/icons/large/inv_plate_outdoorarathor_d_01_glove.jpg',
#  222438: 'https://wow.zamimg.com/images/wow/icons/large/inv_knife_1h_arathoroutdoor_d_01.jpg',
#  222439: 'https://wow.zamimg.com/images/wow/icons/large/inv_knife_1h_arathoroutdoor_d_01.jpg',
#  222440: 'https://wow.zamimg.com/images/wow/icons/large/inv_sword_1h_arathor_c_01.jpg',
#  222441: 'https://wow.zamimg.com/images/wow/icons/large/inv_glaive_1h_arathoroutdoor_d_01.jpg',
#  222442: 'https://wow.zamimg.com/images/wow/icons/large/inv_mace_1h_arathoroutdoor_d_01.jpg',
#  222443: 'https://wow.zamimg.com/images/wow/icons/large/inv_axe_2h_earthendungeon_c_01.jpg',
#  222444: 'https://wow.zamimg.com/images/wow/icons/large/inv_sword_1h_arathor_c_01.jpg',
#  222445: 'https://wow.zamimg.com/images/wow/icons/large/inv_axe_1h_arathoroutdoor_d_01.jpg',
#  222446: 'https://wow.zamimg.com/images/wow/icons/large/inv_hand_1h_undergroundquest_b_01.jpg',
#  222447: 'https://wow.zamimg.com/images/wow/icons/large/inv_sword_2h_earthendungeon_c_01.jpg',
#  222448: 'https://wow.zamimg.com/images/wow/icons/large/inv_polearm_2h_arathoroutdoor_d_01.jpg',
#  222449: 'https://wow.zamimg.com/images/wow/icons/large/inv_mace_2h_earthendungeon_c_02.jpg',
#  222450: 'https://wow.zamimg.com/images/wow/icons/large/inv_mace_2h_earthendungeon_c_02.jpg',
#  222451: 'https://wow.zamimg.com/images/wow/icons/large/inv_axe_1h_arathoroutdoor_d_01.jpg',
#  222458: 'https://wow.zamimg.com/images/wow/icons/large/inv_plate_outdoorarathor_d_01_boot.jpg',
#  222459: 'https://wow.zamimg.com/images/wow/icons/large/inv_shield_1h_arathoroutdoor_d_01.jpg',
#  222463: 'https://wow.zamimg.com/images/wow/icons/large/inv_knife_1h_arathoroutdoor_d_01.jpg',
#  222464: 'https://wow.zamimg.com/images/wow/icons/large/inv_knife_1h_arathoroutdoor_d_01.jpg',
#  222465: 'https://wow.zamimg.com/images/wow/icons/large/inv_knife_1h_arathoroutdoor_d_01.jpg',
#  222466: 'https://wow.zamimg.com/images/wow/icons/large/inv_sword_1h_earthendungeon_c_02.jpg',
#  222467: 'https://wow.zamimg.com/images/wow/icons/large/inv_hand_1h_undergroundquest_b_01.jpg',
#  222468: 'https://wow.zamimg.com/images/wow/icons/large/inv_mace_2h_earthendungeon_c_01.jpg',
#  222469: 'https://wow.zamimg.com/images/wow/icons/large/inv_axe_1h_undergroundquest_b_03.jpg',
#  222470: 'https://wow.zamimg.com/images/wow/icons/large/inv_axe_2h_undergroundquest_b_01.jpg',
#  222471: 'https://wow.zamimg.com/images/wow/icons/large/inv_boot_plate_undergroundquest_b_01.jpg',
#  222472: 'https://wow.zamimg.com/images/wow/icons/large/inv_chest_plate_undergroundquest_b_01.jpg',
#  222473: 'https://wow.zamimg.com/images/wow/icons/large/inv_belt_plate_undergroundquest_b_01.jpg',
#  222474: 'https://wow.zamimg.com/images/wow/icons/large/inv_shield_1h_undergroundquest_b_02.jpg',
#  222475: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_plate_undergroundquest_b_01.jpg',
#  222476: 'https://wow.zamimg.com/images/wow/icons/large/inv_pant_plate_undergroundquest_b_01.jpg',
#  222477: 'https://wow.zamimg.com/images/wow/icons/large/inv_bracer_plate_undergroundquest_b_01.jpg',
#  222478: 'https://wow.zamimg.com/images/wow/icons/large/inv_shoulder_plate_undergroundquest_b_01.jpg',
#  222479: 'https://wow.zamimg.com/images/wow/icons/large/inv_glove_plate_undergroundquest_b_01.jpg',
#  222480: 'https://wow.zamimg.com/images/wow/icons/large/inv_knife_1h_leatherworking_b_01.jpg',
#  222481: 'https://wow.zamimg.com/images/wow/icons/large/inv_axe_1h_miningpick_a_01.jpg',
#  222482: 'https://wow.zamimg.com/images/wow/icons/large/inv_knife_1h_skinning_a_01.jpg',
#  222483: 'https://wow.zamimg.com/images/wow/icons/large/inv_professions_tailoringneedleset02.jpg',
#  222484: 'https://wow.zamimg.com/images/wow/icons/large/inv_knife_1h_leatherworking_b_01.jpg',
#  222485: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_lunchbox_red.jpg',
#  222486: 'https://wow.zamimg.com/images/wow/icons/large/trade_archaeology_ogre2handedhammer.jpg',
#  222487: 'https://wow.zamimg.com/images/wow/icons/large/inv_blacksmithing_toolbox_01.jpg',
#  222488: 'https://wow.zamimg.com/images/wow/icons/large/inv_axe_1h_herbalism_b_01.jpg',
#  222489: 'https://wow.zamimg.com/images/wow/icons/large/inv_axe_1h_miningpick_a_01.jpg',
#  222490: 'https://wow.zamimg.com/images/wow/icons/large/inv_knife_1h_skinning_a_01.jpg',
#  222491: 'https://wow.zamimg.com/images/wow/icons/large/inv_professions_tailoringneedleset01.jpg',
#  222492: 'https://wow.zamimg.com/images/wow/icons/large/inv_knife_1h_leatherworking_b_01.jpg',
#  222493: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_specialization_leatherworking_harvesting_color2.jpg',
#  222494: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_blacksmithing_consumable_sharpeningstone_color2.jpg',
#  222495: 'https://wow.zamimg.com/images/wow/icons/large/inv_blacksmithing_toolbox_02.jpg',
#  222499: 'https://wow.zamimg.com/images/wow/icons/large/inv_gizmo_adamantiteframe.jpg',
#  222502: 'https://wow.zamimg.com/images/wow/icons/large/inv_blacksmithing_modifiedcraftingreagent_blue.jpg',
#  222505: 'https://wow.zamimg.com/images/wow/icons/large/inv_blacksmithing_modifiedcraftingreagent_green.jpg',
#  222508: 'https://wow.zamimg.com/images/wow/icons/large/inv_blacksmithing_modifiedcraftingreagent_red.jpg',
#  222511: 'https://wow.zamimg.com/images/wow/icons/large/inv_gizmo_bronzeframework_01.jpg',
#  222514: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enggizmos_26.jpg',
#  222520: 'https://wow.zamimg.com/images/wow/icons/large/inv_mace_1h_kobold_hammer_a_01.jpg',
#  222523: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_blacksmithing_consumable_key_color1.jpg',
#  225366: 'https://wow.zamimg.com/images/wow/icons/large/inv_axe_1h_undergroundquest_b_02.jpg',
#  225367: 'https://wow.zamimg.com/images/wow/icons/large/inv_knife_1h_undergroundquest_b_01.jpg',
#  225371: 'https://wow.zamimg.com/images/wow/icons/large/inv_mace_1h_undergroundquest_b_02.jpg',
#  225373: 'https://wow.zamimg.com/images/wow/icons/large/inv_shield_1h_undergroundquest_b_01.jpg',
#  225374: 'https://wow.zamimg.com/images/wow/icons/large/inv_axe_1h_undergroundquest_b_01.jpg',
#  225375: 'https://wow.zamimg.com/images/wow/icons/large/inv_knife_1h_undergroundquest_b_02.jpg',
#  225376: 'https://wow.zamimg.com/images/wow/icons/large/inv_sword_2h_undergroundquest_b_01.jpg',
#  225377: 'https://wow.zamimg.com/images/wow/icons/large/inv_sword_1h_undergroundquest_b_01.jpg',
#  225660: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_blacksmithing_consumable_repairhammer_color2.jpg',
#  223650: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223653: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223656: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223659: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223662: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223665: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223668: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223671: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223674: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223677: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223680: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223683: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223686: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223689: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223692: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223695: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223698: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223701: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223704: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223707: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223708: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223713: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223716: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223719: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223721: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223725: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223727: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223731: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223734: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223737: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223740: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223747: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223750: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223753: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223756: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223759: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223762: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223765: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223768: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223772: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223775: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223778: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223781: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223784: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223787: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223790: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223793: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223796: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  223800: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enchantedscroll.jpg',
#  224069: 'https://wow.zamimg.com/images/wow/icons/large/inv_crestupgrade_xalatath_weathered_enchanted.jpg',
#  224072: 'https://wow.zamimg.com/images/wow/icons/large/inv_crestupgrade_xalatath_runed_enchanted.jpg',
#  224073: 'https://wow.zamimg.com/images/wow/icons/large/inv_crestupgrade_xalatath_gilded_enchanted-.jpg',
#  224105: 'https://wow.zamimg.com/images/wow/icons/large/trade_alchemy_potiond1.jpg',
#  224108: 'https://wow.zamimg.com/images/wow/icons/large/trade_alchemy_potiond5.jpg',
#  224111: 'https://wow.zamimg.com/images/wow/icons/large/trade_alchemy_potiond6.jpg',
#  224114: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_1h_enchantingrod_b_01.jpg',
#  224115: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_1h_enchantingrod_b_01.jpg',
#  224116: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_1h_enchantingrod_b_01.jpg',
#  224173: 'https://wow.zamimg.com/images/wow/icons/large/inv_enchant_dustspirit.jpg',
#  224178: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_powder_thorium.jpg',
#  224300: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224301: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224302: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224303: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224304: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224305: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224306: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224307: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224308: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224309: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224310: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224311: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224312: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224313: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224314: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224315: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224316: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224317: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224318: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224319: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224320: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224321: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224322: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224323: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mask_fittedalpha_b_01_nightborne_02.jpg',
#  224404: 'https://wow.zamimg.com/images/wow/icons/large/inv_wand_1h_kultirasquest_b_01.jpg',
#  224405: 'https://wow.zamimg.com/images/wow/icons/large/inv_wand_1h_arathoroutdoor_d_01.jpg',
#  219931: 'https://wow.zamimg.com/images/wow/icons/large/ability_pvp_gladiatormedallion.jpg',
#  219932: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_token_argentdawn3.jpg',
#  219933: 'https://wow.zamimg.com/images/wow/icons/large/ability_warrior_endlessrage.jpg',
#  222546: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_profession_book_alchemy.jpg',
#  222547: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_profession_book_tailoring.jpg',
#  222548: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_profession_book_inscription.jpg',
#  222549: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_profession_book_leatherworking.jpg',
#  222550: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_profession_book_enchanting.jpg',
#  222551: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_profession_book_jewelcrafting.jpg',
#  222552: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_profession_book_herbalism.jpg',
#  222553: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_specialization_professionbook_mining_orig.jpg',
#  222554: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_profession_book_blacksmithing.jpg',
#  222555: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_herb_arathorsspear_crystalized.jpg',
#  222558: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_specialreagentfoozles_coolegg_red.jpg',
#  222565: 'https://wow.zamimg.com/images/wow/icons/large/inv_offhand_1h_undergroundquest_b_02.jpg',
#  222566: 'https://wow.zamimg.com/images/wow/icons/large/inv_offhand_1h_arathoroutdoor_d_01.jpg',
#  222567: 'https://wow.zamimg.com/images/wow/icons/large/inv_staff_2h_arathoroutdoor_d_01.jpg',
#  222568: 'https://wow.zamimg.com/images/wow/icons/large/inv_staff_2h_arathoroutdoor_d_01.jpg',
#  222569: 'https://wow.zamimg.com/images/wow/icons/large/inv_staff_2h_undergroundquest_b_01.jpg',
#  222570: 'https://wow.zamimg.com/images/wow/icons/large/inv_staff_2h_undergroundquest_b_02.jpg',
#  222573: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_1h_scribesquill_b_01_silver.jpg',
#  222574: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_1h_scribesquill_b_01_gold.jpg',
#  222575: 'https://wow.zamimg.com/images/wow/icons/large/inv_alchemy_90_modifiedreagent_yellow.jpg',
#  222576: 'https://wow.zamimg.com/images/wow/icons/large/inv_alchemy_90_modifiedreagent_purple.jpg',
#  222577: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_1h_mixingspoon_b_01.jpg',
#  222578: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_1h_rollingpin_b_01.jpg',
#  222579: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_scroll_02_uprez.jpg',
#  222582: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_scroll_02_uprez_color2.jpg',
#  222585: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_scroll_02_uprez_color3.jpg',
#  222588: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_scroll_02_uprez_color4.jpg',
#  222591: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_scroll_02_uprez_color2.jpg',
#  222594: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_scroll_02_uprez_color5.jpg',
#  222597: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_trade_archaeology_apexisscroll_uprez.jpg',
#  222600: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_trade_archaeology_apexisscroll_uprez_color4.jpg',
#  222603: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_trade_archaeology_apexisscroll_uprez_color2.jpg',
#  222606: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_trade_archaeology_apexisscroll_uprez_color3.jpg',
#  222609: 'https://wow.zamimg.com/images/wow/icons/large/inv_inscriptions_ink_purple.jpg',
#  222615: 'https://wow.zamimg.com/images/wow/icons/large/inv_inscriptions_ink_yellow.jpg',
#  222621: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_specialization_professionbook_engineering_color2.jpg',
#  222626: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_80_scroll_uprez.jpg',
#  222629: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_80_scroll_uprez_color1.jpg',
#  222632: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_80_scroll_uprez_color2.jpg',
#  222635: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_80_warscroll_fortitude_uprez.jpg',
#  222638: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_80_warscroll_fortitude_uprez_color2.jpg',
#  222641: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_80_warscroll_fortitude_uprez_color3.jpg',
#  222644: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription2_repcontracts_80_warscroll_fortitude_uprez_color5.jpg',
#  222649: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_specialization_professionbook_skinning_color1.jpg',
#  225368: 'https://wow.zamimg.com/images/wow/icons/large/inv_polearm_2h_undergroundquest_b_02.jpg',
#  225369: 'https://wow.zamimg.com/images/wow/icons/large/inv_staff_2h_undergroundquest_b_02.jpg',
#  225372: 'https://wow.zamimg.com/images/wow/icons/large/inv_offhand_1h_undergroundquest_b_01.jpg',
#  226022: 'https://wow.zamimg.com/images/wow/icons/large/inv_inscriptions_darkmoonsigil_purple.jpg',
#  226025: 'https://wow.zamimg.com/images/wow/icons/large/inv_inscriptions_darkmoonsigil_red.jpg',
#  226028: 'https://wow.zamimg.com/images/wow/icons/large/inv_inscriptions_darkmoonsigil_teal.jpg',
#  226031: 'https://wow.zamimg.com/images/wow/icons/large/inv_inscriptions_darkmoonsigil_blue.jpg',
#  226034: 'https://wow.zamimg.com/images/wow/icons/large/inv_inscriptions_vantus_rune_orange.jpg',
#  211806: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_blackfollowing.jpg',
#  213453: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color4_3.jpg',
#  213456: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color4_1.jpg',
#  213459: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color4_2.jpg',
#  213462: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem_color5.jpg',
#  213465: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color5_2.jpg',
#  213468: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color5_3.jpg',
#  213471: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color5_1.jpg',
#  213474: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem_color3.jpg',
#  213477: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color1_2.jpg',
#  213480: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color1_3.jpg',
#  213483: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color1_1.jpg',
#  213486: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem_color2.jpg',
#  213489: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color2_2.jpg',
#  213492: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color2_3.jpg',
#  213495: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color2_1.jpg',
#  213498: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem_color1.jpg',
#  213501: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color3_2.jpg',
#  213504: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color3_4.jpg',
#  213507: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color3_3.jpg',
#  213510: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem-hybrid_color3_1.jpg',
#  213515: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_cut-standart-gem_color4.jpg',
#  213738: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_metagem_b.jpg',
#  213744: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_gem_x4_metagem_cut.jpg',
#  213747: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_cutgemsuperior6.jpg',
#  213748: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_epicgem_01.jpg',
#  213749: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_epicgem_uncut_01.jpg',
#  213750: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_nightelfknife.jpg',
#  213753: 'https://wow.zamimg.com/images/wow/icons/large/inv_archaeology_70_highborne_violetglassvessel.jpg',
#  213756: 'https://wow.zamimg.com/images/wow/icons/large/trade_archaeology_nerubian_obelisk.jpg',
#  213759: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_jewelcrafting_prism_transparent.jpg',
#  213762: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_jewelcrafting_blottedsand_color1.jpg',
#  213765: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_49.jpg',
#  213768: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_jewelcrafting3_rainbowprism_color2.jpg',
#  213771: 'https://wow.zamimg.com/images/wow/icons/large/inv_enchant_prismaticsphere.jpg',
#  213774: 'https://wow.zamimg.com/images/wow/icons/large/spell_priest_divinestar_holy.jpg',
#  213777: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_90_elethiumsetting.jpg',
#  213779: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_uncutgemnormal.jpg',
#  213782: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_uncutgemnormal1.jpg',
#  213785: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_uncutgemnormal3.jpg',
#  213788: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_uncutgemnormal4.jpg',
#  213791: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_uncutgemnormal2.jpg',
#  215117: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_scribesspecs_b_01_gold.jpg',
#  215119: 'https://wow.zamimg.com/images/wow/icons/large/inv_professions_inscription_scribesmagnifyingglass_silver.jpg',
#  215120: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_jewelersspecs_b_01.jpg',
#  215121: 'https://wow.zamimg.com/images/wow/icons/large/inv_offhand_draenei_a_02.jpg',
#  215122: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_scribesspecs_b_01_silver.jpg',
#  215123: 'https://wow.zamimg.com/images/wow/icons/large/inv_professions_inscription_scribesmagnifyingglass_gold.jpg',
#  215124: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_jewelersspecs_b_01.jpg',
#  215125: 'https://wow.zamimg.com/images/wow/icons/large/inv_offhand_draenei_a_02.jpg',
#  215130: 'https://wow.zamimg.com/images/wow/icons/large/inv_11_0_earthen_jewelcraftingring_color2.jpg',
#  215131: 'https://wow.zamimg.com/images/wow/icons/large/inv_11_0_earthen_jewelcraftingnecklace_color2.jpg',
#  215133: 'https://wow.zamimg.com/images/wow/icons/large/inv_11_0_jewelcrafting_ring_color1.jpg',
#  215134: 'https://wow.zamimg.com/images/wow/icons/large/inv_11_0_arathor_necklace_02_color5.jpg',
#  215135: 'https://wow.zamimg.com/images/wow/icons/large/inv_11_0_earthen_earthenring_color1.jpg',
#  215136: 'https://wow.zamimg.com/images/wow/icons/large/inv_11_0_earthen_earthennecklace02_color1.jpg',
#  215137: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelry_ring_91.jpg',
#  215144: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_necklace3_red.jpg',
#  215145: 'https://wow.zamimg.com/images/wow/icons/large/achievement_bg_xkills_avgraveyard.jpg',
#  215147: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_gem_variety_02.jpg',
#  217113: 'https://wow.zamimg.com/images/wow/icons/large/inv_stone_01.jpg',
#  217126: 'https://wow.zamimg.com/images/wow/icons/large/inv_boot_leather_undergroundquest_b_01.jpg',
#  217127: 'https://wow.zamimg.com/images/wow/icons/large/inv_chest_leather_undergroundquest_b_01.jpg',
#  217128: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_leather_undergroundquest_b_01.jpg',
#  217129: 'https://wow.zamimg.com/images/wow/icons/large/inv_shoulder_leather_undergroundquest_b_01.jpg',
#  217130: 'https://wow.zamimg.com/images/wow/icons/large/inv_belt_leather_undergroundquest_b_01.jpg',
#  217131: 'https://wow.zamimg.com/images/wow/icons/large/inv_pant_leather_undergroundquest_b_01.jpg',
#  217132: 'https://wow.zamimg.com/images/wow/icons/large/inv_glove_leather_undergroundquest_b_01.jpg',
#  217133: 'https://wow.zamimg.com/images/wow/icons/large/inv_bracer_leather_undergroundquest_b_01.jpg',
#  217134: 'https://wow.zamimg.com/images/wow/icons/large/inv_boot_mail_undergroundquest_b_01.jpg',
#  217135: 'https://wow.zamimg.com/images/wow/icons/large/inv_chest_mail_undergroundquest_b_01.jpg',
#  217136: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mail_undergroundquest_b_01.jpg',
#  217137: 'https://wow.zamimg.com/images/wow/icons/large/inv_shoulder_mail_undergroundquest_b_01.jpg',
#  217138: 'https://wow.zamimg.com/images/wow/icons/large/inv_belt_mail_undergroundquest_b_01.jpg',
#  217139: 'https://wow.zamimg.com/images/wow/icons/large/inv_pant_mail_undergroundquest_b_01.jpg',
#  217140: 'https://wow.zamimg.com/images/wow/icons/large/inv_glove_mail_undergroundquest_b_01.jpg',
#  217141: 'https://wow.zamimg.com/images/wow/icons/large/inv_bracer_mail_undergroundquest_b_01.jpg',
#  219327: 'https://wow.zamimg.com/images/wow/icons/large/inv_leather_outdoorarathor_d_01_boot.jpg',
#  219328: 'https://wow.zamimg.com/images/wow/icons/large/inv_leather_outdoorarathor_d_01_robe.jpg',
#  219329: 'https://wow.zamimg.com/images/wow/icons/large/inv_leather_outdoorarathor_d_01_helm.jpg',
#  219330: 'https://wow.zamimg.com/images/wow/icons/large/inv_leather_outdoorarathor_d_01_shoulder.jpg',
#  219331: 'https://wow.zamimg.com/images/wow/icons/large/inv_leather_outdoorarathor_d_01_belt.jpg',
#  219332: 'https://wow.zamimg.com/images/wow/icons/large/inv_leather_outdoorarathor_d_01_pant.jpg',
#  219333: 'https://wow.zamimg.com/images/wow/icons/large/inv_leather_outdoorarathor_d_01_glove.jpg',
#  219334: 'https://wow.zamimg.com/images/wow/icons/large/inv_leather_outdoorarathor_d_01_bracer.jpg',
#  219335: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_outdoorarathor_d_01_boot.jpg',
#  219336: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_outdoorarathor_d_01_robe.jpg',
#  219337: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_outdoorarathor_d_01_helm.jpg',
#  219338: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_outdoorarathor_d_01_shoulder.jpg',
#  219339: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_outdoorarathor_d_01_belt.jpg',
#  219340: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_outdoorarathor_d_01_pant.jpg',
#  219341: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_outdoorarathor_d_01_glove.jpg',
#  219342: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_outdoorarathor_d_01_bracer.jpg',
#  219470: 'https://wow.zamimg.com/images/wow/icons/large/inv_boot_leather_undergroundquest_b_01.jpg',
#  219471: 'https://wow.zamimg.com/images/wow/icons/large/inv_bracer_leather_undergroundquest_b_01.jpg',
#  219472: 'https://wow.zamimg.com/images/wow/icons/large/inv_chest_leather_undergroundquest_b_01.jpg',
#  219473: 'https://wow.zamimg.com/images/wow/icons/large/inv_boot_mail_undergroundquest_b_01.jpg',
#  219474: 'https://wow.zamimg.com/images/wow/icons/large/inv_bracer_mail_undergroundquest_b_01.jpg',
#  219475: 'https://wow.zamimg.com/images/wow/icons/large/inv_chest_mail_undergroundquest_b_01.jpg',
#  219476: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_leather_undergroundquest_b_01.jpg',
#  219477: 'https://wow.zamimg.com/images/wow/icons/large/inv_shoulder_leather_undergroundquest_b_01.jpg',
#  219478: 'https://wow.zamimg.com/images/wow/icons/large/inv_glove_leather_undergroundquest_b_01.jpg',
#  219479: 'https://wow.zamimg.com/images/wow/icons/large/inv_pant_leather_undergroundquest_b_01.jpg',
#  219480: 'https://wow.zamimg.com/images/wow/icons/large/inv_belt_leather_undergroundquest_b_01.jpg',
#  219481: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_mail_undergroundquest_b_01.jpg',
#  219482: 'https://wow.zamimg.com/images/wow/icons/large/inv_shoulder_mail_undergroundquest_b_01.jpg',
#  219483: 'https://wow.zamimg.com/images/wow/icons/large/inv_glove_mail_undergroundquest_b_01.jpg',
#  219484: 'https://wow.zamimg.com/images/wow/icons/large/inv_pant_mail_undergroundquest_b_01.jpg',
#  219485: 'https://wow.zamimg.com/images/wow/icons/large/inv_belt_mail_undergroundquest_b_01.jpg',
#  219489: 'https://wow.zamimg.com/images/wow/icons/large/inv_leather_outdoorarathor_d_01_boot.jpg',
#  219492: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_outdoorarathor_d_01_glove.jpg',
#  219495: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_emberweavebandage.jpg',
#  219501: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_outdoorarathor_d_01_bracer.jpg',
#  219502: 'https://wow.zamimg.com/images/wow/icons/large/inv_belt_leather_undergroundquest_b_01.jpg',
#  219504: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_skinning_craftedoptionalreagent_studdedleatherswatch_color2.jpg',
#  219507: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_outdoorarathor_d_01_robe.jpg',
#  219508: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_outdoorarathor_d_01_boot.jpg',
#  219509: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_outdoorarathor_d_01_belt.jpg',
#  219511: 'https://wow.zamimg.com/images/wow/icons/large/inv_leather_outdoorarathor_d_01_bracer.jpg',
#  219512: 'https://wow.zamimg.com/images/wow/icons/large/inv_leather_outdoorarathor_d_01_robe.jpg',
#  219513: 'https://wow.zamimg.com/images/wow/icons/large/inv_leather_outdoorarathor_d_01_glove.jpg',
#  219861: 'https://wow.zamimg.com/images/wow/icons/large/inv_cape_special_herbalism_b_01.jpg',
#  219862: 'https://wow.zamimg.com/images/wow/icons/large/inv_cape_special_skinning_c_01.jpg',
#  219863: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_skinning_a_01.jpg',
#  219864: 'https://wow.zamimg.com/images/wow/icons/large/inv_armor_engineering_b_01_orange.jpg',
#  219865: 'https://wow.zamimg.com/images/wow/icons/large/inv_armor_leatherworking_b_01.jpg',
#  219866: 'https://wow.zamimg.com/images/wow/icons/large/inv_armor_helm_alchemy_b_01.jpg',
#  219867: 'https://wow.zamimg.com/images/wow/icons/large/inv_cape_special_herbalism_b_01.jpg',
#  219868: 'https://wow.zamimg.com/images/wow/icons/large/inv_cape_special_skinning_c_01.jpg',
#  219869: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_skinning_a_01.jpg',
#  219870: 'https://wow.zamimg.com/images/wow/icons/large/inv_armor_engineering_b_01_orange.jpg',
#  219871: 'https://wow.zamimg.com/images/wow/icons/large/inv_armor_leatherworking_b_01.jpg',
#  219872: 'https://wow.zamimg.com/images/wow/icons/large/inv_armor_helm_alchemy_b_01.jpg',
#  219873: 'https://wow.zamimg.com/images/wow/icons/large/inv_tabard_blacksmithing_b_01_brown.jpg',
#  219874: 'https://wow.zamimg.com/images/wow/icons/large/inv_tabard_blacksmithing_b_01_black.jpg',
#  219875: 'https://wow.zamimg.com/images/wow/icons/large/inv_tabard_jewelcrafting_b_01.jpg',
#  219876: 'https://wow.zamimg.com/images/wow/icons/large/inv_tabard_jewelcrafting_b_01.jpg',
#  219880: 'https://wow.zamimg.com/images/wow/icons/large/inv_craftedhides_base.jpg',
#  219883: 'https://wow.zamimg.com/images/wow/icons/large/inv_craftedhides_crystalline-powder.jpg',
#  219886: 'https://wow.zamimg.com/images/wow/icons/large/inv_craftedhides_writhing_essence.jpg',
#  219889: 'https://wow.zamimg.com/images/wow/icons/large/inv_craftedhides_viridescent_spores.jpg',
#  219892: 'https://wow.zamimg.com/images/wow/icons/large/inv_craftedhides_leyline_residue.jpg',
#  219898: 'https://wow.zamimg.com/images/wow/icons/large/inv_12_skinning_gloomchitin2.jpg',
#  219901: 'https://wow.zamimg.com/images/wow/icons/large/inv_bandages_stormtouched.jpg',
#  219905: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_skinning_consumable_leatherdrums_color3.jpg',
#  219906: 'https://wow.zamimg.com/images/wow/icons/large/inv_armorkit_arathi.jpg',
#  219909: 'https://wow.zamimg.com/images/wow/icons/large/inv_armorkit_lightning_imbued.jpg',
#  219912: 'https://wow.zamimg.com/images/wow/icons/large/inv_armorkit_standard.jpg',
#  217117: 'https://wow.zamimg.com/images/wow/icons/large/inv_pant_cloth_undergroundquest_b_01.jpg',
#  217118: 'https://wow.zamimg.com/images/wow/icons/large/inv_shoulder_cloth_undergroundquest_b_01.jpg',
#  217119: 'https://wow.zamimg.com/images/wow/icons/large/inv_boot_cloth_undergroundquest_b_01.jpg',
#  217120: 'https://wow.zamimg.com/images/wow/icons/large/inv_bracer_cloth_undergroundquest_b_01.jpg',
#  217121: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_cloth_undergroundquest_b_01.jpg',
#  217122: 'https://wow.zamimg.com/images/wow/icons/large/inv_glove_cloth_undergroundquest_b_01.jpg',
#  217123: 'https://wow.zamimg.com/images/wow/icons/large/inv_chest_cloth_undergroundquest_b_01.jpg',
#  217124: 'https://wow.zamimg.com/images/wow/icons/large/inv_belt_cloth_undergroundquest_b_01.jpg',
#  217125: 'https://wow.zamimg.com/images/wow/icons/large/inv_cape_cloth_undergroundquest_b_01.jpg',
#  222798: 'https://wow.zamimg.com/images/wow/icons/large/inv_12_tailoring_rare_cloth_violet_rare-cloth.jpg',
#  222801: 'https://wow.zamimg.com/images/wow/icons/large/inv_12_tailoring_rare_cloth_orange-_rare-cloth.jpg',
#  222804: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_clothrare_color2.jpg',
#  222807: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_glove.jpg',
#  222808: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_boot.jpg',
#  222809: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_glove.jpg',
#  222810: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_boot.jpg',
#  222811: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_bracer.jpg',
#  222812: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_bracer.jpg',
#  222814: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_boot.jpg',
#  222815: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_bracer.jpg',
#  222816: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_belt.jpg',
#  222817: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_cape.jpg',
#  222818: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_helm.jpg',
#  222819: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_chest.jpg',
#  222820: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_pant.jpg',
#  222821: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_shoulder.jpg',
#  222822: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_outdoorarathor_d_01_glove.jpg',
#  222832: 'https://wow.zamimg.com/images/wow/icons/large/inv_boot_cloth_undergroundquest_b_01.jpg',
#  222833: 'https://wow.zamimg.com/images/wow/icons/large/inv_bracer_cloth_undergroundquest_b_01.jpg',
#  222834: 'https://wow.zamimg.com/images/wow/icons/large/inv_belt_cloth_undergroundquest_b_01.jpg',
#  222835: 'https://wow.zamimg.com/images/wow/icons/large/inv_cape_cloth_undergroundquest_b_01.jpg',
#  222836: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_cloth_undergroundquest_b_01.jpg',
#  222837: 'https://wow.zamimg.com/images/wow/icons/large/inv_robe_cloth_undergroundquest_b_01.jpg',
#  222838: 'https://wow.zamimg.com/images/wow/icons/large/inv_pant_cloth_undergroundquest_b_01.jpg',
#  222839: 'https://wow.zamimg.com/images/wow/icons/large/inv_shoulder_cloth_undergroundquest_b_01.jpg',
#  222840: 'https://wow.zamimg.com/images/wow/icons/large/inv_glove_cloth_undergroundquest_b_01.jpg',
#  222841: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_herbalism_b_01.jpg',
#  222842: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_fishing_b_01.jpg',
#  222843: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_enchantinghat_b_01.jpg',
#  222844: 'https://wow.zamimg.com/images/wow/icons/large/inv_chest_armor_tailoringrobe_b_01.jpg',
#  222845: 'https://wow.zamimg.com/images/wow/icons/large/inv_armor_alchemy_b_01.jpg',
#  222846: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_chefhat_b_01.jpg',
#  222847: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_herbalism_b_01.jpg',
#  222848: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_fishing_b_01.jpg',
#  222849: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_enchantinghat_b_01.jpg',
#  222850: 'https://wow.zamimg.com/images/wow/icons/large/inv_armor_alchemy_b_01.jpg',
#  222851: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_chefhat_b_01.jpg',
#  222852: 'https://wow.zamimg.com/images/wow/icons/large/inv_chest_armor_tailoringrobe_b_01.jpg',
#  222853: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_craftingoptionalreagent_extrapockets_color4.jpg',
#  222854: 'https://wow.zamimg.com/images/wow/icons/large/inv_tailoring_reagent_bag_orange_reagent_bag.jpg',
#  222855: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_craftingoptionalreagent_extrapockets_color1.jpg',
#  222856: 'https://wow.zamimg.com/images/wow/icons/large/inv_tailoring_reagent_bag_violet_reagent_bag.jpg',
#  222859: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_potionbag_special.jpg',
#  222860: 'https://wow.zamimg.com/images/wow/icons/large/inv_tailoring_reagent_bag_orange_reagent_bag.jpg',
#  222861: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_bag_horadricsatchel.jpg',
#  222862: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_bag_enchantedrunecloth.jpg',
#  222863: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_bag_21.jpg',
#  222864: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_bag_felclothbag.jpg',
#  222865: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_bag_herbpouch.jpg',
#  222866: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_bag_36.jpg',
#  222867: 'https://wow.zamimg.com/images/wow/icons/large/reliquarybag_icon.jpg',
#  222868: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_tailoringconsumable_color2.jpg',
#  222871: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_tailoringconsumable_color3.jpg',
#  222876: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_polishingcloth_color1.jpg',
#  222879: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_polishingcloth_color3.jpg',
#  222882: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_purchasedthread_color2.jpg',
#  222885: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_purchasedthread_color1.jpg',
#  222888: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_craftingoptionalreagent_enhancedspellthread_color3.jpg',
#  222891: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_craftingoptionalreagent_enhancedspellthread_color3.jpg',
#  222894: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_craftingoptionalreagent_enhancedspellthread_color3.jpg',
#  224440: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_skinning_consumable_clothbandages_color1.jpg',
#  224832: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_wovenbolt_air.jpg',
#  224852: 'https://wow.zamimg.com/images/wow/icons/large/inv_backpack_wrathion_c_01.jpg',
#  225729: 'https://wow.zamimg.com/images/wow/icons/large/inv_tailoring_80_nylonthread.jpg',
#  225936: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_coinbag05.jpg',
#  225592: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_84_roastclefthoof.jpg',
#  222705: 'https://wow.zamimg.com/images/wow/icons/large/inv_mushroom_10.jpg',
#  222703: 'https://wow.zamimg.com/images/wow/icons/large/inv_tradeskill_cooking_stonesouppot01.jpg',
# ...
#  223966: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_160_fish_87.jpg',
#  225855: 'https://wow.zamimg.com/images/wow/icons/large/inv_cooking_90_cinnamonbonefishstew.jpg',
#  223970: 'https://wow.zamimg.com/images/wow/icons/large/inv_cooking_90_biscuitscaviar.jpg',
#  223969: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_vendor_soysauce.jpg',
#  221865: 'https://wow.zamimg.com/images/wow/icons/large/inv_manufacturedpart2_purple.jpg',
#  221868: 'https://wow.zamimg.com/images/wow/icons/large/inv_manufacturedpart4_green.jpg',
#  221862: 'https://wow.zamimg.com/images/wow/icons/large/inv_manufacturedpart3_blue.jpg',
#  225987: 'https://wow.zamimg.com/images/wow/icons/large/inv_eng_bottledelements.jpg',
#  221859: 'https://wow.zamimg.com/images/wow/icons/large/inv_manufacturedpart1_orange.jpg',
#  221853: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_engineering_manufacturedparts_gizmo_fireironbolts_black.jpg',
#  221856: 'https://wow.zamimg.com/images/wow/icons/large/spell_mekkatorque_bot_greenspring.jpg',
#  221926: 'https://wow.zamimg.com/images/wow/icons/large/achievement_bg_returnxflags_def_wsg.jpg',
#  221932: 'https://wow.zamimg.com/images/wow/icons/large/inv_engineering_sonicenvironmentenhancer.jpg',
#  221923: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enggizmos_05.jpg',
#  221938: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_bomb_09.jpg',
#  221941: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enggizmos_24.jpg',
#  221935: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_bomb_08.jpg',
#  221920: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_engineering_purchasedparts_color4.jpg',
#  221917: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_engineering_purchasedparts_color2.jpg',
#  221914: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_engineering_purchasedparts_color3.jpg',
#  221911: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_engineering_purchasedparts_color5.jpg',
#  221805: 'https://wow.zamimg.com/images/wow/icons/large/inv_cloth_dragonquest_b_01_bracer.jpg',
#  221808: 'https://wow.zamimg.com/images/wow/icons/large/inv_bracer_plate_dragonquest_b_01.jpg',
#  221804: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_gnomish_c_01_red.jpg',
#  221802: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_gnomish_c_01_red.jpg',
#  221969: 'https://wow.zamimg.com/images/wow/icons/large/inv_firearm_2h_arathoroutdoor_d_01.jpg',
#  221801: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_gnomish_c_01_red.jpg',
#  221803: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_gnomish_c_01_red.jpg',
#  221806: 'https://wow.zamimg.com/images/wow/icons/large/inv_leather_dragonquest_b_01_bracer.jpg',
#  221807: 'https://wow.zamimg.com/images/wow/icons/large/inv_mail_dragonquest_b_01_bracer.jpg',
#  225646: 'https://wow.zamimg.com/images/wow/icons/large/inv_firearm_2h_engineering_c_01_blue.jpg',
#  225642: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_engineering_b_02_goblin.jpg',
#  225645: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_engineering_b_02_goblin.jpg',
#  225643: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_engineering_b_02_goblin.jpg',
#  225644: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_engineering_b_02_goblin.jpg',
#  221789: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_engineering_b_01_orange.jpg',
#  221791: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_2h_fishingpole_b_01.jpg',
#  221798: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_1h_engineeringmultitool_b_01_orange.jpg',
#  221796: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_mining_a_01.jpg',
#  221793: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_1h_jewelerschisel_a_01.jpg',
#  221800: 'https://wow.zamimg.com/images/wow/icons/large/inv_cape_special_mining_c_01.jpg',
#  221787: 'https://wow.zamimg.com/images/wow/icons/large/inv_sword_1h_tailoring_b_01.jpg',
#  221788: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_engineering_b_01_orange.jpg',
#  221790: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_2h_fishingpole_b_01.jpg',
#  221797: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_1h_engineeringmultitool_b_01_orange.jpg',
#  221795: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_mining_a_01.jpg',
#  221792: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_1h_jewelerschisel_a_01.jpg',
#  221799: 'https://wow.zamimg.com/images/wow/icons/large/inv_cape_special_mining_c_01.jpg',
#  221786: 'https://wow.zamimg.com/images/wow/icons/large/inv_sword_1h_tailoring_b_01.jpg',
#  224586: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_engineering2_boxofbombs_dangerous_color1.jpg',
#  221880: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_engineering_explosives_1_color2.jpg',
#  221876: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_engineering_explosives_1_color1.jpg',
#  221872: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_engineering_explosives_1_color3.jpg',
#  219387: 'https://wow.zamimg.com/images/wow/icons/large/inv_eng_crate.jpg',
#  221962: 'https://wow.zamimg.com/images/wow/icons/large/ability_vehicle_siegeengineram.jpg',
#  221964: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_-selfiecamera_02.jpg',
#  221966: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_engineering_device_gadget3_color2.jpg',
#  219403: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_trinket6oih_lanterna1.jpg',
#  221967: 'https://wow.zamimg.com/images/wow/icons/large/inv_dwarvenmechboss_gold.jpg',
#  221953: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_engineering_manufacturedparts_electricalparts_color3.jpg',
#  221945: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_enggizmos_27.jpg',
#  221949: 'https://wow.zamimg.com/images/wow/icons/large/10prof_portabletable_engineering01.jpg',
#  221957: 'https://wow.zamimg.com/images/wow/icons/large/achievement_dungeon_ulduarraid_irongolem_01.jpg',
#  221959: 'https://wow.zamimg.com/images/wow/icons/large/inv_engineering_intradalaranwormholegenerator.jpg',
#  221904: 'https://wow.zamimg.com/images/wow/icons/large/inv_tinkermodule_yellow.jpg',
#  221908: 'https://wow.zamimg.com/images/wow/icons/large/inv_tinkermodule_red.jpg',
#  217155: 'https://wow.zamimg.com/images/wow/icons/large/inv_bracer_cloth_undergroundquest_b_01.jpg',
#  217151: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_gnomish_c_01_red.jpg',
#  217156: 'https://wow.zamimg.com/images/wow/icons/large/inv_bracer_leather_undergroundquest_b_01.jpg',
#  217152: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_gnomish_c_01_red.jpg',
#  217157: 'https://wow.zamimg.com/images/wow/icons/large/inv_bracer_mail_undergroundquest_b_01.jpg',
#  217153: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_gnomish_c_01_red.jpg',
#  217158: 'https://wow.zamimg.com/images/wow/icons/large/inv_bracer_plate_undergroundquest_b_01.jpg',
#  217154: 'https://wow.zamimg.com/images/wow/icons/large/inv_helm_armor_gnomish_c_01_red.jpg',
#  225370: 'https://wow.zamimg.com/images/wow/icons/large/inv_firearm_2h_undergroundquest_b_01.jpg',
#  211296: 'https://wow.zamimg.com/images/wow/icons/large/inv_spark_whole_violet.jpg',
#  210796: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_herb_mycobloom.jpg',
#  210805: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_herb_blessingblossom.jpg',
#  210802: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_herb_orbinid.jpg',
#  210799: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_herb_luredrop.jpg',
#  210808: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_herb_arathorsspear.jpg',
#  213610: 'https://wow.zamimg.com/images/wow/icons/large/inv_crystalline_powder_orange.jpg',
#  213611: 'https://wow.zamimg.com/images/wow/icons/large/inv_writhing_samples_violet.jpg',
#  213197: 'https://wow.zamimg.com/images/wow/icons/large/inv_nulllotus_shadow.jpg',
#  213612: 'https://wow.zamimg.com/images/wow/icons/large/inv_viridescent_spores_violet.jpg',
#  213613: 'https://wow.zamimg.com/images/wow/icons/large/inv_leyline_residue_violet.jpg',
#  211805: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_legion_gooamberblue_chunk.jpg',
#  212754: 'https://wow.zamimg.com/images/wow/icons/large/inv_guild_cauldron_b.jpg',
#  210815: 'https://wow.zamimg.com/images/wow/icons/large/inv_alchemy_71_potion4.jpg',
#  210814: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_gearcraft_artisansmettle_color3.jpg',
#  221756: 'https://wow.zamimg.com/images/wow/icons/large/trade_alchemy_dpotion_c15.jpg',
#  221763: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_starspecklemushroom.jpg',
#  210221: 'https://wow.zamimg.com/images/wow/icons/large/inv_competition_placement_ribbon_green.jpg',
#  226202: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_blacksmithing_craftedoptional_blacksmithdye_fire.jpg',
#  210930: 'https://wow.zamimg.com/images/wow/icons/large/inv_ore_bismuth.jpg',
#  210933: 'https://wow.zamimg.com/images/wow/icons/large/inv_ore_nerubian_red.jpg',
#  221758: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_tinderboxclosed01.jpg',
#  210939: 'https://wow.zamimg.com/images/wow/icons/large/inv_nullstone_shadow.jpg',
#  210936: 'https://wow.zamimg.com/images/wow/icons/large/inv_ore_ironclaw_normal.jpg',
#  219013: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_redsaberonfang.jpg',
#  221754: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_blacksmithing_craftedoptional_reinforcedmetalplating_color02.jpg',
#  221757: 'https://wow.zamimg.com/images/wow/icons/large/inv_skinning_80_snakescales.jpg',
#  219946: 'https://wow.zamimg.com/images/wow/icons/large/inv_enchanting_dust_color3.jpg',
#  219949: 'https://wow.zamimg.com/images/wow/icons/large/inv_enchanting_shard_color3.jpg',
#  218338: 'https://wow.zamimg.com/images/wow/icons/large/spell_nature_unrelentingstorm.jpg',
#  219952: 'https://wow.zamimg.com/images/wow/icons/large/inv_enchanting_crystal_color2.jpg',
#  220788: 'https://wow.zamimg.com/images/wow/icons/large/inv_crestupgrade_xalatath_weathered.jpg',
#  220790: 'https://wow.zamimg.com/images/wow/icons/large/inv_crestupgrade_xalatath_runed.jpg',
#  220789: 'https://wow.zamimg.com/images/wow/icons/large/inv_crestupgrade_xalatath_gilded.jpg',
#  227208: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_1h_enchantingrod_b_01.jpg',
#  226205: 'https://wow.zamimg.com/images/wow/icons/large/shaman_pvp_ripplingwaters.jpg',
#  226204: 'https://wow.zamimg.com/images/wow/icons/large/inv_inscription_parchmentvar06.jpg',
#  224802: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription3_pigments_blue.jpg',
#  224805: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription3_pigments_red.jpg',
#  222612: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription3_pigments_bronze.jpg',
#  222618: 'https://wow.zamimg.com/images/wow/icons/large/inv_inscription_pigment_tranquil01.jpg',
#  222680: 'https://wow.zamimg.com/images/wow/icons/large/inv_inscriptions_darkmoondeckevolution_0.jpg',
#  219672: 'https://wow.zamimg.com/images/wow/icons/large/inv_inscriptions_darkmoondeckshine_0.jpg',
#  222653: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_inscription_darkmooncards_spore_blank.jpg',
#  222671: 'https://wow.zamimg.com/images/wow/icons/large/inv_inscriptions_darkmoondeckvivacity_0.jpg',
#  213399: 'https://wow.zamimg.com/images/wow/icons/large/trade_archaeology_arakkoa_crystalshard.jpg',
#  212498: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_uncut-standart-gem_color4.jpg',
#  213219: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_powder_mithril.jpg',
#  212495: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_uncut-standart-gem_color5.jpg',
#  212505: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_uncut-standart-gem_color2.jpg',
#  212511: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_uncut-standart-gem_color1.jpg',
#  212508: 'https://wow.zamimg.com/images/wow/icons/large/inv_jewelcrafting_uncut-standart-gem_color3.jpg',
#  215236: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_gem_ruby_01.jpg',
#  213398: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_jewelcrafting_stones_color2.jpg',
#  3423: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_flower_02.jpg',
#  212664: 'https://wow.zamimg.com/images/wow/icons/large/inv_12_skinning_stormchargedleather2.jpg',
#  212667: 'https://wow.zamimg.com/images/wow/icons/large/inv_12_skinning_gloomchitin.jpg',
#  212670: 'https://wow.zamimg.com/images/wow/icons/large/inv_12_skinning_thunderoushide1.jpg',
#  212674: 'https://wow.zamimg.com/images/wow/icons/large/inv_12_skinning_sunlesscarapace1.jpg',
#  218336: 'https://wow.zamimg.com/images/wow/icons/large/inv_12_skinning_gloomchitin1.jpg',
#  218339: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_pelt_12.jpg',
#  218337: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_bone_07.jpg',
#  224764: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_tailoring_purchasedthread_color3.jpg',
#  222795: 'https://wow.zamimg.com/images/wow/icons/large/inv_tailoring_modifiedcraftingreagent_magenta.jpg',
#  222789: 'https://wow.zamimg.com/images/wow/icons/large/inv_tailoring_modifiedcraftingreagent_indigo.jpg',
#  222792: 'https://wow.zamimg.com/images/wow/icons/large/inv_tailoring_modifiedcraftingreagent_orange.jpg',
#  228930: 'https://wow.zamimg.com/images/wow/icons/large/inv_bandages_tailoring.jpg',
#  222738: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_meat_rawtigersteak.jpg',
#  222700: 'https://wow.zamimg.com/images/wow/icons/large/inv_enchant_dustspirit.jpg',
#  222695: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_vendor_scallions.jpg',
#  222737: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_driedneedlemushrooms.jpg',
#  222739: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_117_heartysoup.jpg',
#  222741: 'https://wow.zamimg.com/images/wow/icons/large/inv_fishing_innards_meat_sleeper.jpg',
#  224762: 'https://wow.zamimg.com/images/wow/icons/large/inv_drink_waterskin_06.jpg',
#  225876: 'https://wow.zamimg.com/images/wow/icons/large/inv_cooking_80_powderedsugar.jpg',
#  222697: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_vendor_blackpepper.jpg',
#  222696: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_vendor_jadesquash.jpg',
#  222701: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_legion_flaked-sea-salt.jpg',
#  220149: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_fishing_fishdragon_red.jpg',
#  222699: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_food_43.jpg',
#  220146: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_fish_99.jpg',
#  220151: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_fish_34.jpg',
#  220153: 'https://wow.zamimg.com/images/wow/icons/large/inv_deepseafish.jpg',
#  223977: 'https://wow.zamimg.com/images/wow/icons/large/spell_mage_flameorb.jpg',
#  225912: 'https://wow.zamimg.com/images/wow/icons/large/inv_cooking_80_choralhoney1.jpg',
#  225883: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_fish_97.jpg',
#  228956: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_1h_bucket_b_01.jpg',
#  228414: 'https://wow.zamimg.com/images/wow/icons/large/ability_hunter_razorwire.jpg',
#  219150: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_gear_08.jpg',
#  227769: 'https://wow.zamimg.com/images/wow/icons/large/spell_mekkatorque_bot_yellowbolt.jpg',
#  227770: 'https://wow.zamimg.com/images/wow/icons/large/inv_eng_superchargedengine.jpg',
#  227771: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_alchemy_engineersgrease_color2.jpg',
#  227772: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_engineering2_pvpflaregun_color1.jpg',
#  227773: 'https://wow.zamimg.com/images/wow/icons/large/inv_10_engineering_manufacturedparts_reavesbattery_frost.jpg',
#  227774: 'https://wow.zamimg.com/images/wow/icons/large/inv_misc_ticket_tarot_madness.jpg'}

# %% [markdown]
# # Update ItemIDs to be Rank 3

# %%
method = "LOAD"
itemIDfile = STATIC_DIR+'itemIDUpdates.pkl'

if not os.path.isfile(itemIDfile) or method == 'UPDATE':
    old_ids = items['itemID'].astype(int).to_numpy()
    all_jobs = [joblib.delayed(check_id)(old_id) for old_id in old_ids]
    results = joblib.Parallel(n_jobs=num_cores, verbose=10)(all_jobs)
    new_ids = {int(k):int(v) for d in results for k,v in d.items()}
    new_ids_df = pd.DataFrame()
    new_ids_df['oldID'] = new_ids.keys()
    new_ids_df['newID'] = new_ids.values()
    new_ids_df.to_pickle(itemIDfile)
elif os.path.isfile(itemIDfile) and method == 'LOAD':
    new_ids = pd.read_pickle(itemIDfile)
    new_ids = dict(zip(new_ids['oldID'].values, new_ids['newID'].values))

# %%
#manual ID fixes
for old_id in new_ids.keys():
    if old_id in range(224300, 224324): #gleeful glamours
        new_ids[old_id] = old_id+48
    elif old_id == 219952: #refulgent crystal
        new_ids[old_id] = 219955
    elif old_id == 212670: #thunderous hide
        new_ids[old_id] = 212673

# %%
#ensure all items with a rank 3 are listed at rank 3
assert -1 not in new_ids.values()

# %%
#update itemIDs in both dataframes
all_data['itemID'] = all_data['itemID'].map(new_ids)
items['itemID'] = items['itemID'].map(new_ids)

# %%
#update all item ids that are not at rank 3 with the found rank 3 ids
all_data['reagents'] = all_data['reagents'].apply(updateReagents, args=(new_ids,))

# %% [markdown]
# # Add Difficulties

# %%
#all mats rank 2
all_data['skill2'] = all_data['skill1']+all_data['difficulty']*0.2

#all mats rank 3
all_data['skill3'] = all_data['skill1']+all_data['difficulty']*0.4

extraDiff = {'safetyComponent':10,
             'missive':5,
             'embellishment':5,
             'weatheredCrest':100,
             'runedCrest':10,
             'gildedCrest':20,
             'combatant':0,
             'aspirant':50,
             'gladiator':150}

#safetycomponent+embellishment not currently possible
all_data['difficulty_safetycomponent'] = all_data['difficulty'] + extraDiff['safetyComponent']
all_data['difficulty_missive'] = all_data['difficulty'] + extraDiff['missive']
all_data['difficulty_embellishment'] = all_data['difficulty'] + extraDiff['embellishment']
all_data['difficulty_safetycomponent_missive'] = all_data['difficulty']
all_data['difficulty_missive_embellishment'] = all_data['difficulty'] + extraDiff['missive'] + extraDiff['embellishment']
all_data['difficulty_weathered'] = all_data['difficulty'] + extraDiff['weatheredCrest']
all_data['difficulty_weathered_safetycomponent'] = all_data['difficulty'] + extraDiff['weatheredCrest'] + extraDiff['safetyComponent']
all_data['difficulty_weathered_missive'] = all_data['difficulty'] + extraDiff['weatheredCrest'] + extraDiff['missive']
all_data['difficulty_weathered_embellishment'] = all_data['difficulty'] + extraDiff['weatheredCrest'] + extraDiff['embellishment']
all_data['difficulty_weathered_safetycomponent_missive'] = all_data['difficulty'] + extraDiff['weatheredCrest'] + extraDiff['safetyComponent'] + extraDiff['missive']
all_data['difficulty_weathered_missive_embellishment'] = all_data['difficulty'] + extraDiff['weatheredCrest'] + extraDiff['missive'] + extraDiff['embellishment']
all_data['difficulty_runed'] = all_data['difficulty'] + extraDiff['runedCrest']
all_data['difficulty_runed_safetycomponent'] = all_data['difficulty'] + extraDiff['runedCrest'] + extraDiff['safetyComponent']
all_data['difficulty_runed_missive'] = all_data['difficulty'] + extraDiff['runedCrest'] + extraDiff['missive']
all_data['difficulty_runed_embellishment'] = all_data['difficulty'] + extraDiff['runedCrest'] + extraDiff['embellishment']
all_data['difficulty_runed_safetycomponent_missive'] = all_data['difficulty'] + extraDiff['runedCrest'] + extraDiff['safetyComponent'] + extraDiff['missive']
all_data['difficulty_runed_missive_embellishment'] = all_data['difficulty'] + extraDiff['runedCrest'] + extraDiff['missive'] + extraDiff['embellishment']
all_data['difficulty_gilded'] = all_data['difficulty'] + extraDiff['gildedCrest']
all_data['difficulty_gilded_safetycomponent'] = all_data['difficulty'] + extraDiff['gildedCrest'] + extraDiff['safetyComponent']
all_data['difficulty_gilded_missive'] = all_data['difficulty'] + extraDiff['gildedCrest'] + extraDiff['missive']
all_data['difficulty_gilded_embellishment'] = all_data['difficulty'] + extraDiff['gildedCrest'] + extraDiff['embellishment']
all_data['difficulty_gilded_safetycomponent_missive'] = all_data['difficulty'] + extraDiff['gildedCrest'] + extraDiff['safetyComponent'] + extraDiff['missive']
all_data['difficulty_gilded_missive_embellishment'] = all_data['difficulty'] + extraDiff['gildedCrest'] + extraDiff['missive'] + extraDiff['embellishment']
all_data['difficulty_combatant'] = all_data['difficulty']+extraDiff['combatant']
all_data['difficulty_combatant_missive'] = all_data['difficulty']+extraDiff['combatant']+extraDiff['missive']
all_data['difficulty_combatant_embellishment'] = all_data['difficulty']+extraDiff['combatant']+extraDiff['embellishment']
all_data['difficulty_combatant_missive_embellishment'] = all_data['difficulty']+extraDiff['combatant']+extraDiff['missive']+extraDiff['embellishment']
all_data['difficulty_aspirant'] = all_data['difficulty']+extraDiff['aspirant']
all_data['difficulty_aspirant_missive'] = all_data['difficulty']+extraDiff['aspirant']+extraDiff['missive']
all_data['difficulty_aspirant_embellishment'] = all_data['difficulty']+extraDiff['aspirant']+extraDiff['embellishment']
all_data['difficulty_aspirant_missive_embellishment'] = all_data['difficulty']+extraDiff['aspirant']+extraDiff['missive']+extraDiff['embellishment']
all_data['difficulty_gladiator'] = all_data['difficulty']+extraDiff['gladiator']
all_data['difficulty_gladiator_missive'] = all_data['difficulty']+extraDiff['gladiator']+extraDiff['missive']
all_data['difficulty_gladiator_embellishment'] = all_data['difficulty']+extraDiff['gladiator']+extraDiff['embellishment']
all_data['difficulty_gladiator_missive_embellishment'] = all_data['difficulty']+extraDiff['gladiator']+extraDiff['missive']+extraDiff['embellishment']

# %%
modifiers = ['', '_safetycomponent', '_missive', '_embellishment', '_safetycomponent_missive', 
             '_missive_embellishment', '_weathered', '_weathered_safetycomponent', 
             '_weathered_safetycomponent_missive', '_weathered_missive', '_weathered_embellishment',
             '_weathered_missive_embellishment', '_runed', '_runed_safetycomponent', '_runed_safetycomponent_missive', '_runed_missive',
             '_runed_embellishment', '_runed_missive_embellishment', '_gilded', '_gilded_safetycomponent', 
             '_gilded_missive', '_gilded_safetycomponent_missive', '_gilded_embellishment', 
             '_gilded_missive_embellishment', '_combatant', '_combatant_missive', '_combatant_embellishment', 
             '_combatant_missive_embellishment', '_aspirant', '_aspirant_missive', '_aspirant_embellishment', 
             '_aspirant_missive_embellishment', '_gladiator', '_gladiator_missive', '_gladiator_embellishment', 
             '_gladiator_missive_embellishment']
    
for modifier in modifiers:
    all_data['rank1mats_outcome'+modifier] = all_data.apply(lambda row: outcomeQuality(row['skill1'], 
                                                                                       row['difficulty'+modifier], 
                                                                                       row['tag']), axis=1)
    all_data['rank2mats_outcome'+modifier] = all_data.apply(lambda row: outcomeQuality(row['skill2'], 
                                                                                       row['difficulty'+modifier], 
                                                                                       row['tag']), axis=1)
    all_data['rank3mats_outcome'+modifier] = all_data.apply(lambda row: outcomeQuality(row['skill3'], 
                                                                                       row['difficulty'+modifier], 
                                                                                       row['tag']), axis=1)

# %% [markdown]
# # Proper Case tag field

# %%
all_data['tag'] = all_data['tag'].apply(lambda x: x.title() if x != "gear (pvp)" else "Gear (PvP)")

# %% [markdown]
# # Remove pd.NA and Sorting

# %%
all_data = all_data.reset_index(drop=True)

all_data['character'] = all_data['character'].replace({pd.NA:None, 'None':None})
all_data = all_data.sort_values(by=['profession', 'item'], ascending=[True, True])

assert(len(all_data['character'].unique()==8) or len(all_data['character'].unique()==9))

# %% [markdown]
# # File Saving

# %%
items.to_pickle(STATIC_DIR+'items_TWW.pkl')

# %%
all_data.to_pickle(STATIC_DIR+'data_TWW.pkl')

# %%
items = pd.read_pickle(STATIC_DIR+'items_TWW.pkl')
all_data = pd.read_pickle(STATIC_DIR+'data_TWW.pkl')

# %% [markdown]
# # Issue Testing
