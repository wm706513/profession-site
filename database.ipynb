# %%
import MySQLdb
import sshtunnel
import os
import numpy as np
import pandas as pd
from dotenv import load_dotenv

# %%
load_dotenv()
DATA_DIR = './static/data'

# %%
class Database:
    def __init__(self, ssh_address, ssh_username, ssh_password, remote_address, 
                 database_user, database_password, database_name):
        self._ssh_address = ssh_address
        self._ssh_username = ssh_username
        self._ssh_password = ssh_password
        self._remote_address = remote_address
        self._database_user = database_user
        self._database_password = database_password
        self._database_name = database_name
        self.tables = self._get_tables()
        
    def get_connection(self, tunnel):
        """Sets up a connection to the MySQL database"""
        connection = MySQLdb.connect(
            user = self._database_user,
            passwd = self._database_password,
            host = "127.0.0.1",
            port = tunnel.local_bind_port,
            db = self._database_name
        )
        
        return connection
    
    def get_tunnel(self):
        """Sets up and returns an SSH tunnel"""
        sshtunnel.SSH_TIMEOUT = 10.0
        sshtunnel.TUNNEL_TIMEOUT = 10.0
        tunnel = sshtunnel.SSHTunnelForwarder(
            ssh_address_or_host = (self._ssh_address),
            ssh_username = self._ssh_username,
            ssh_password = self._ssh_password,
            remote_bind_address = (self._remote_address, 3306)
        )
        
        return tunnel
    
    def _get_tables(self):
        """Returns a list of all tables in the database by querying the database"""
        with self.get_tunnel() as tunnel:
            connection = self.get_connection(tunnel)
            cursor = connection.cursor()
            cursor.execute("SHOW TABLES;")
            results = cursor.fetchall()
            
        results = [result[0] for result in results]
        return results
    
    def get_tables(self):
        """Returns a list of all tables in the database by referencing the object"""
        return self.tables
    
    def is_table(self, tableName):
        if len(self.tables) == 0:
            self.tables = self.get_tables()

        return tableName in self.tables
    
    def create_table(self, tableName, tableCols, dataTypes, primaryKey=None):
        """Creates a new table in the database"""
        assert not self.is_table(tableName), f"{tableName} already exists."            
    
        command = "CREATE TABLE"
        command += f" {tableName} ( "
        for col, dtype in zip(tableCols, dataTypes):
            command += f'`{col}` {dtype}, '
            
        if primaryKey is not None:
            command += "PRIMARY KEY ("
            for key in primaryKey:
                command += f"`{key}`, "
                
        command = command[:-2]
        command += ')'
        
        print(command)
        with self.get_tunnel() as tunnel:
            connection = self.get_connection(tunnel)
            cursor = connection.cursor()
            cursor.execute(command)
            connection.commit()
            
        # add the table name into the list of tables within the object for increased speed
        self.tables += [f"{tableName}"]
            
    def describe_table(self, tableName):
        """Returns a description of the table"""
        assert self.is_table(tableName), f"{tableName} does not exist."
        
        with self.get_tunnel() as tunnel:
            connection = self.get_connection(tunnel)
            cursor = connection.cursor()
            cursor.execute(f"DESCRIBE {tableName};")
            results = cursor.fetchall()
            
        results = pd.DataFrame(data=results, columns=['Field', 'Type', 'Null', 'Key', 'Default', 'Extra'])
        return results
    
    def drop_table(self, tableName):
        """Drops a table form the database"""
        assert self.is_table(tableName), f"{tableName} does not exist."
        
        with self.get_tunnel() as tunnel:
            connection = self.get_connection(tunnel)
            cursor = connection.cursor()
            cursor.execute(f"DROP TABLE {tableName}")
            connection.commit()
            
    def insert_values(self, tableName, values, columns=None):
        assert isinstance(values, list), "values must be a list of tuples"
        assert len(values) > 0, "values cannot be empty"
        numCols = len(values[0])
        for row in values:
            assert isinstance(row, tuple), "values must be a list of tuples"
            assert len(row) == numCols, "all tuples must be the same number of values"
            
        if columns is not None:
            assert isinstance(columns, list), "columns must be a list of strings"
            assert all([isinstance(col, str) for col in columns]), "columns must be a list of strings"
            assert len(columns) == numCols, f"number of columns provided ({len(columns)}) does not match number of columns in provided data ({numCols})"
        
        command = f"INSERT INTO {tableName} "
        if columns is not None:
            command += "("
            for column in columns:
                command += f"`{column}`, "
            command = command[:-2] #replace comma with closing parenthesis
            command += ') '
        command += "VALUES "
        for row in values:
            command += str(row)+', '
        command = command[:-2]
        command += ';'
    
        with self.get_tunnel() as tunnel:
            connection = self.get_connection(tunnel)
            cursor = connection.cursor()
            cursor.execute(command)
            connection.commit()

# %%
SSH_ADDRESS = os.getenv('SSH_ADDRESS')
SSH_USER = os.getenv('SSH_USER')
SSH_PASS = os.getenv('SSH_PASS')
REMOTE_ADDRESS = os.getenv('REMOTE_ADDRESS')
DB_USER = os.getenv('DB_USER')
DB_PASS = os.getenv('DB_PASS')
DB_NAME = os.getenv('DB_NAME')

database = Database(SSH_ADDRESS, SSH_USER, SSH_PASS, REMOTE_ADDRESS, DB_USER, DB_PASS, DB_NAME)

# %%
items_df = pd.read_pickle(f'{DATA_DIR}/items_DF.pkl')
data_df = pd.read_pickle(f'{DATA_DIR}/data_DF.pkl')
items_tww = pd.read_pickle(f'{DATA_DIR}/items_TWW.pkl')
data_tww = pd.read_pickle(f'{DATA_DIR}/data_TWW.pkl')

# %%
dtype_conversion = {
    'int64':'INT',
    'int32':'INT',
    'string':'TINYTEXT',
    'object':'TINYTEXT',
    'O':'TINYTEXT',
    'float64':'DOUBLE',
    'float32':'DOUBLE',
    'bool':'BOOL'
}

if not database.is_table('items_df'):
    dtypes = [dtype_conversion.get(str(dtype)) for dtype in items_df.dtypes]
    database.create_table('items_df', list(items_df.columns), dataTypes=dtypes)
    
if not database.is_table('items_tww'):
    dtypes = [dtype_conversion.get(str(dtype)) for dtype in items_tww.dtypes]
    database.create_table('items_tww', list(items_tww.columns), dataTypes=dtypes)

if not database.is_table('data_df'):
    dtypes = [dtype_conversion.get(str(dtype)) for dtype in data_df.dtypes]
    database.create_table('data_df', list(data_df.columns), dataTypes=dtypes)
    
if not database.is_table('data_tww'):
    dtypes = [dtype_conversion.get(str(dtype)) for dtype in data_tww.dtypes]
    database.create_table('data_tww', list(data_tww.columns), dataTypes=dtypes)
# Out:
# CREATE TABLE data_df ( `profession` TINYTEXT, `character` TINYTEXT, `id` INT, `item` TINYTEXT, `reagents` TINYTEXT, `tag` TINYTEXT, `rarity` TINYTEXT, `difficulty` DOUBLE, `skill1` DOUBLE, `hsv` DOUBLE, `inspiration_skill` DOUBLE, `inspiration_percent` DOUBLE, `base_quantity` TINYTEXT, `multicraft_percent` DOUBLE, `has_reagent_qualities` BOOL, `has_embellishment_slot` BOOL, `has_missive_slot` BOOL, `has_tinker_slot` BOOL, `has_crest_slot` BOOL, `icon` TINYTEXT, `skill2` DOUBLE, `skill3` DOUBLE, `difficulty_tinker` DOUBLE, `difficulty_missive` DOUBLE, `difficulty_embellishment` DOUBLE, `difficulty_tinker_missive` DOUBLE, `difficulty_missive_embellishment` DOUBLE, `difficulty_whelpling` DOUBLE, `difficulty_whelpling_tinker` DOUBLE, `difficulty_whelpling_missive` DOUBLE, `difficulty_whelpling_embellishment` DOUBLE, `difficulty_whelpling_tinker_missive` DOUBLE, `difficulty_whelpling_missive_embellishment` DOUBLE, `difficulty_wyrm` DOUBLE, `difficulty_wyrm_tinker` DOUBLE, `difficulty_wyrm_missive` DOUBLE, `difficulty_wyrm_embellishment` DOUBLE, `difficulty_wyrm_tinker_missive` DOUBLE, `difficulty_wyrm_missive_embellishment` DOUBLE, `difficulty_aspect` DOUBLE, `difficulty_aspect_tinker` DOUBLE, `difficulty_aspect_missive` DOUBLE, `difficulty_aspect_embellishment` DOUBLE, `difficulty_aspect_tinker_missive` DOUBLE, `difficulty_aspect_missive_embellishment` DOUBLE, `odds1` DOUBLE, `odds_hsv1` DOUBLE, `odds2` DOUBLE, `odds_hsv2` DOUBLE, `odds3` DOUBLE, `odds_hsv3` DOUBLE, `odds_tinker1` DOUBLE, `odds_tinker_hsv1` DOUBLE, `odds_tinker2` DOUBLE, `odds_tinker_hsv2` DOUBLE, `odds_tinker3` DOUBLE, `odds_tinker_hsv3` DOUBLE, `odds_missive1` DOUBLE, `odds_missive_hsv1` DOUBLE, `odds_missive2` DOUBLE, `odds_missive_hsv2` DOUBLE, `odds_missive3` DOUBLE, `odds_missive_hsv3` DOUBLE, `odds_embellishment1` DOUBLE, `odds_embellishment_hsv1` DOUBLE, `odds_embellishment2` DOUBLE, `odds_embellishment_hsv2` DOUBLE, `odds_embellishment3` DOUBLE, `odds_embellishment_hsv3` DOUBLE, `odds_tinker_missive1` DOUBLE, `odds_tinker_missive_hsv1` DOUBLE, `odds_tinker_missive2` DOUBLE, `odds_tinker_missive_hsv2` DOUBLE, `odds_tinker_missive3` DOUBLE, `odds_tinker_missive_hsv3` DOUBLE, `odds_missive_embellishment1` DOUBLE, `odds_missive_embellishment_hsv1` DOUBLE, `odds_missive_embellishment2` DOUBLE, `odds_missive_embellishment_hsv2` DOUBLE, `odds_missive_embellishment3` DOUBLE, `odds_missive_embellishment_hsv3` DOUBLE, `odds_whelpling1` DOUBLE, `odds_whelpling_hsv1` DOUBLE, `odds_whelpling2` DOUBLE, `odds_whelpling_hsv2` DOUBLE, `odds_whelpling3` DOUBLE, `odds_whelpling_hsv3` DOUBLE, `odds_whelpling_tinker1` DOUBLE, `odds_whelpling_tinker_hsv1` DOUBLE, `odds_whelpling_tinker2` DOUBLE, `odds_whelpling_tinker_hsv2` DOUBLE, `odds_whelpling_tinker3` DOUBLE, `odds_whelpling_tinker_hsv3` DOUBLE, `odds_whelpling_tinker_missive1` DOUBLE, `odds_whelpling_tinker_missive_hsv1` DOUBLE, `odds_whelpling_tinker_missive2` DOUBLE, `odds_whelpling_tinker_missive_hsv2` DOUBLE, `odds_whelpling_tinker_missive3` DOUBLE, `odds_whelpling_tinker_missive_hsv3` DOUBLE, `odds_whelpling_missive1` DOUBLE, `odds_whelpling_missive_hsv1` DOUBLE, `odds_whelpling_missive2` DOUBLE, `odds_whelpling_missive_hsv2` DOUBLE, `odds_whelpling_missive3` DOUBLE, `odds_whelpling_missive_hsv3` DOUBLE, `odds_whelpling_embellishment1` DOUBLE, `odds_whelpling_embellishment_hsv1` DOUBLE, `odds_whelpling_embellishment2` DOUBLE, `odds_whelpling_embellishment_hsv2` DOUBLE, `odds_whelpling_embellishment3` DOUBLE, `odds_whelpling_embellishment_hsv3` DOUBLE, `odds_whelpling_missive_embellishment1` DOUBLE, `odds_whelpling_missive_embellishment_hsv1` DOUBLE, `odds_whelpling_missive_embellishment2` DOUBLE, `odds_whelpling_missive_embellishment_hsv2` DOUBLE, `odds_whelpling_missive_embellishment3` DOUBLE, `odds_whelpling_missive_embellishment_hsv3` DOUBLE, `odds_wyrm1` DOUBLE, `odds_wyrm_hsv1` DOUBLE, `odds_wyrm2` DOUBLE, `odds_wyrm_hsv2` DOUBLE, `odds_wyrm3` DOUBLE, `odds_wyrm_hsv3` DOUBLE, `odds_wyrm_tinker1` DOUBLE, `odds_w ...
# CREATE TABLE data_tww ( `itemID` INT, `profession` TINYTEXT, `character` TINYTEXT, `item` TINYTEXT, `icon` TINYTEXT, `reagents` TINYTEXT, `tag` TINYTEXT, `rarity` TINYTEXT, `difficulty` DOUBLE, `skill1` DOUBLE, `baseQuantity` TINYTEXT, `multicraftPercent` DOUBLE, `hasReagentQualities` BOOL, `hasEmbellishmentSlot` BOOL, `hasMissiveSlot` BOOL, `hasSafetyComponent` BOOL, `hasCrestSlot` BOOL, `skill2` DOUBLE, `skill3` DOUBLE, `difficulty_safetycomponent` DOUBLE, `difficulty_missive` DOUBLE, `difficulty_embellishment` DOUBLE, `difficulty_safetycomponent_missive` DOUBLE, `difficulty_missive_embellishment` DOUBLE, `difficulty_weathered` DOUBLE, `difficulty_weathered_safetycomponent` DOUBLE, `difficulty_weathered_missive` DOUBLE, `difficulty_weathered_embellishment` DOUBLE, `difficulty_weathered_safetycomponent_missive` DOUBLE, `difficulty_weathered_missive_embellishment` DOUBLE, `difficulty_runed` DOUBLE, `difficulty_runed_safetycomponent` DOUBLE, `difficulty_runed_missive` DOUBLE, `difficulty_runed_embellishment` DOUBLE, `difficulty_runed_safetycomponent_missive` DOUBLE, `difficulty_runed_missive_embellishment` DOUBLE, `difficulty_gilded` DOUBLE, `difficulty_gilded_safetycomponent` DOUBLE, `difficulty_gilded_missive` DOUBLE, `difficulty_gilded_embellishment` DOUBLE, `difficulty_gilded_safetycomponent_missive` DOUBLE, `difficulty_gilded_missive_embellishment` DOUBLE, `difficulty_combatant` DOUBLE, `difficulty_combatant_missive` DOUBLE, `difficulty_combatant_embellishment` DOUBLE, `difficulty_combatant_missive_embellishment` DOUBLE, `difficulty_aspirant` DOUBLE, `difficulty_aspirant_missive` DOUBLE, `difficulty_aspirant_embellishment` DOUBLE, `difficulty_aspirant_missive_embellishment` DOUBLE, `difficulty_gladiator` DOUBLE, `difficulty_gladiator_missive` DOUBLE, `difficulty_gladiator_embellishment` DOUBLE, `difficulty_gladiator_missive_embellishment` DOUBLE, `rank1mats_outcome` INT, `rank2mats_outcome` INT, `rank3mats_outcome` INT, `rank1mats_outcome_safetycomponent` INT, `rank2mats_outcome_safetycomponent` INT, `rank3mats_outcome_safetycomponent` INT, `rank1mats_outcome_missive` INT, `rank2mats_outcome_missive` INT, `rank3mats_outcome_missive` INT, `rank1mats_outcome_embellishment` INT, `rank2mats_outcome_embellishment` INT, `rank3mats_outcome_embellishment` INT, `rank1mats_outcome_safetycomponent_missive` INT, `rank2mats_outcome_safetycomponent_missive` INT, `rank3mats_outcome_safetycomponent_missive` INT, `rank1mats_outcome_missive_embellishment` INT, `rank2mats_outcome_missive_embellishment` INT, `rank3mats_outcome_missive_embellishment` INT, `rank1mats_outcome_weathered` INT, `rank2mats_outcome_weathered` INT, `rank3mats_outcome_weathered` INT, `rank1mats_outcome_weathered_safetycomponent` INT, `rank2mats_outcome_weathered_safetycomponent` INT, `rank3mats_outcome_weathered_safetycomponent` INT, `rank1mats_outcome_weathered_safetycomponent_missive` INT, `rank2mats_outcome_weathered_safetycomponent_missive` INT, `rank3mats_outcome_weathered_safetycomponent_missive` INT, `rank1mats_outcome_weathered_missive` INT, `rank2mats_outcome_weathered_missive` INT, `rank3mats_outcome_weathered_missive` INT, `rank1mats_outcome_weathered_embellishment` INT, `rank2mats_outcome_weathered_embellishment` INT, `rank3mats_outcome_weathered_embellishment` INT, `rank1mats_outcome_weathered_missive_embellishment` INT, `rank2mats_outcome_weathered_missive_embellishment` INT, `rank3mats_outcome_weathered_missive_embellishment` INT, `rank1mats_outcome_runed` INT, `rank2mats_outcome_runed` INT, `rank3mats_outcome_runed` INT, `rank1mats_outcome_runed_safetycomponent` INT, `rank2mats_outcome_runed_safetycomponent` INT, `rank3mats_outcome_runed_safetycomponent` INT, `rank1mats_outcome_runed_safetycomponent_missive` INT, `rank2mats_outcome_runed_safetycomponent_missive` INT, `rank3mats_outcome_runed_safetycomponent_missive` INT, `rank1mats_outcome_runed_missive` INT, `rank2mats_outcome_runed_missive` INT, `rank3mats_outcome_runed_missive` INT, `rank1mats_outcom ...

# %%
data_df.columns
# Out:
# Index(['profession', 'character', 'id', 'item', 'reagents', 'tag', 'rarity',
#        'difficulty', 'skill1', 'hsv',
#        ...
#        'odds_aspect_embellishment2', 'odds_aspect_embellishment_hsv2',
#        'odds_aspect_embellishment3', 'odds_aspect_embellishment_hsv3',
#        'odds_aspect_missive_embellishment1',
#        'odds_aspect_missive_embellishment_hsv1',
#        'odds_aspect_missive_embellishment2',
#        'odds_aspect_missive_embellishment_hsv2',
#        'odds_aspect_missive_embellishment3',
#        'odds_aspect_missive_embellishment_hsv3'],
#       dtype='object', length=189)

# %%
data_df[data_df.duplicated(['id', 'item'])]
# Out:
#          profession    character      id  \
# 118   Blacksmithing  Zarastannil  191529
# 215         Cooking   Trillithia  197794
# 216         Cooking   Trillithia  197794
# 291      Enchanting      Linidel  204697
# 293      Enchanting      Linidel  204697
# 299      Enchanting      Linidel  204681
# 301      Enchanting      Linidel  204681
# 295      Enchanting      Linidel  204682
# 297      Enchanting      Linidel  204682
# 225      Enchanting      Linidel  191529
# 322     Engineering   Trillithia  191529
# 501     Inscription    Mellasona  194829
# 502     Inscription    Mellasona  194829
# 428     Inscription    Mellasona  191529
# 461     Inscription    Mellasona  204166
# 463     Inscription    Mellasona  204165
# 465     Inscription    Mellasona  204164
# 467     Inscription    Mellasona  204166
# 469     Inscription    Mellasona  204165
# 471     Inscription    Mellasona  204164
# 558   Jewelcrafting     Nystelil  191529
# 713  Leatherworking     Braevele  193470
# 714  Leatherworking     Braevele  193470
# 649  Leatherworking     Braevele  191529
# 818       Tailoring      Linidel  191529
#
#                                           item  \
# 118                        Illustrious Insight
# 215               Grand Banquet of the Kalu'ak
# 216               Grand Banquet of the Kalu'ak
# 291          Enchanted Aspect's Dreaming Crest
# 293       Enchanted Aspect's Shadowflame Crest
# 299       Enchanted Whelpling's Dreaming Crest
# 301    Enchanted Whelpling's Shadowflame Crest
# 295            Enchanted Wyrm's Dreaming Crest
# 297         Enchanted Wyrm's Shadowflame Crest
# 225                        Illustrious Insight
# 322                        Illustrious Insight
# 501                         Fated Fortune Card
# 502                         Fated Fortune Card
# 428                        Illustrious Insight
# 461                Obsidian Combatant's Emblem
# 463  Obsidian Combatant's Insignia of Alacrity
# 465             Obsidian Combatant's Medallion
# 467                 Verdant Combatant's Emblem
# 469   Verdant Combatant's Insignia of Alacrity
# 471              Verdant Combatant's Medallion
# 558                        Illustrious Insight
# 713                           Feral Hide Drums
# 714                           Feral Hide Drums
# 649                        Illustrious Insight
# 818                        Illustrious Insight
#
#                                               reagents               tag  \
# 118                                       {190456: 50}  Crafting Reagent
# 215  {200061: 2, 197788: 4, 197782: 6, 197787: 6, 1...        Consumable
# 216  {199345: 2, 197789: 4, 197783: 6, 197786: 6, 1...        Consumable
# 291  {194123: 80, 194124: 15, 200113: 4, 204463: 2,...  Crafting Reagent
# 293  {194123: 80, 194124: 15, 200113: 4, 204463: 2,...  Crafting Reagent
# 299      {194123: 30, 194124: 5, 200113: 1, 208395: 1}  Crafting Reagent
# 301      {194123: 30, 194124: 5, 200113: 1, 204193: 1}  Crafting Reagent
# 295  {194123: 60, 194124: 10, 200113: 2, 204463: 1,...  Crafting Reagent
# 297  {194123: 60, 194124: 10, 200113: 2, 204463: 1,...  Crafting Reagent
# 225                                       {190456: 50}  Crafting Reagent
# 322                                       {190456: 50}  Crafting Reagent
# 501                  {194784: 1, 198487: 2, 194852: 2}             Other
# 502                  {194784: 1, 198487: 2, 194858: 2}             Other
# 428                                       {190456: 50}  Crafting Reagent
# 461                  {190450: 3, 194859: 1, 194852: 6}     Gear (Combat)
# 463                  {190450: 3, 194859: 1, 194751: 6}     Gear (Combat)
# 465                  {190450: 3, 194859: 1, 194858: 6}     Gear (Combat)
# 467                 {190450: 4, 194768: 1, 194852: 10}     Gear (Combat)
# 469                 {190450: 4, 194768: 1, 194751: 10}     Gear (Combat)
# 471                 {190450: 4, 194768: 1, 194858: 10}     Gear (Combat)
# 558                                       {190456: 50}  Crafting Reagent
# 713                                        {193218: 1}        Consumable
# 714                                        {193224: 1}        Consumable
# 649                                       {190456: 50}  Crafting Reagent
# 818                                       {190456: 50}  Crafting Reagent
#
#        rarity  difficulty  skill1  hsv  ...  odds_aspect_embellishment2  \
# 118      rare         NaN     NaN  NaN  ...                         NaN
# 215      rare         NaN     NaN  NaN  ...                         NaN
# 216      rare         NaN     NaN  NaN  ...                         NaN
# 291      epic         NaN     NaN  NaN  ...                         NaN
# 293      epic         NaN     NaN  NaN  ...                         NaN
# 299      epic         NaN     NaN  NaN  ...                         NaN
# 301      epic         NaN     NaN  NaN  ...                         NaN
# 295      epic         NaN     NaN  NaN  ...                         NaN
# 297      epic         NaN     NaN  NaN  ...                         NaN
# 225      rare         NaN     NaN  NaN  ...                         NaN
# 322      rare         NaN     NaN  NaN  ...                         NaN
# 501  uncommon         NaN     NaN  NaN  ...                         NaN
# 502  uncommon         NaN     NaN  NaN  ...                         NaN
# 428      rare         NaN     NaN  NaN  ...                         NaN
# 461  uncommon       120.0   182.0  6.0  ...                       100.0
# 463  uncommon       120.0   182.0  6.0  ...                       100.0
# 465  uncommon       120.0   182.0  6.0  ...                       100.0
# 467  uncommon       120.0   182.0  6.0  ...                       100.0
# 469  uncommon       120.0   182.0  6.0  ...                       100.0
# 471  uncommon       120.0   182.0  6.0  ...                       100.0
# 558      rare         NaN     NaN  NaN  ...                         NaN
# 713  uncommon         NaN     NaN  NaN  ...                         NaN
# 714  uncommon         NaN     NaN  NaN  ...                         NaN
# 649      rare         NaN     NaN  NaN  ...                         NaN
# 818      rare         NaN     NaN  NaN  ...                         NaN
#
#      odds_aspect_embellishment_hsv2 odds_aspect_embellishment3  \
# 118                             NaN                        NaN
# 215                             NaN                        NaN
# 216                             NaN                        NaN
# 291                             NaN                        NaN
# 293                             NaN                        NaN
# 299                             NaN                        NaN
# 301                             NaN                        NaN
# 295                             NaN                        NaN
# 297                             NaN                        NaN
# 225                             NaN                        NaN
# 322                             NaN                        NaN
# 501                             NaN                        NaN
# 502                             NaN                        NaN
# 428                             NaN                        NaN
# 461                           100.0                      100.0
# 463                           100.0                      100.0
# 465                           100.0                      100.0
# 467                           100.0                      100.0
# 469                           100.0                      100.0
# 471                           100.0                      100.0
# 558                             NaN                        NaN
# 713                             NaN                        NaN
# 714                             NaN                        NaN
# 649                             NaN                        NaN
# 818                             NaN                        NaN
#
#      odds_aspect_embellishment_hsv3  odds_aspect_missive_embellishment1  \
# 118                             NaN                                 NaN
# 215                             NaN                                 NaN
# 216                             NaN                                 NaN
# 291                             NaN                                 NaN
# 293                             NaN                                 NaN
# 299                             NaN                                 NaN
# 301                             NaN                                 NaN
# 295                             NaN                                 NaN
# 297                             NaN                                 NaN
# 225                             NaN                                 NaN
# 322                             NaN                                 NaN
# 501                             NaN                                 NaN
# 502                             NaN                                 NaN
# 428                             NaN                                 NaN
# 461                           100.0                                33.3
# 463                           100.0                                33.3
# 465                           100.0                                33.3
# 467                           100.0                                33.3
# 469                           100.0                                33.3
# 471                           100.0                                33.3
# 558                             NaN                                 NaN
# 713                             NaN                                 NaN
# 714                             NaN                                 NaN
# 649                             NaN                                 NaN
# 818                             NaN                                 NaN
#
#      odds_aspect_missive_embellishment_hsv1  \
# 118                                     NaN
# 215                                     NaN
# 216                                     NaN
# 291                                     NaN
# 293                                     NaN
# 299                                     NaN
# 301                                     NaN
# 295                                     NaN
# 297                                     NaN
# 225                                     NaN
# 322                                     NaN
# 501                                     NaN
# 502                                     NaN
# 428                                     NaN
# 461                                    33.3
# 463                                    33.3
# 465                                    33.3
# 467                                    33.3
# 469                                    33.3
# 471                                    33.3
# 558                                     NaN
# 713                                     NaN
# 714                                     NaN
# 649                                     NaN
# 818                                     NaN
#
#      odds_aspect_missive_embellishment2  \
# 118                                 NaN
# 215                                 NaN
# 216                                 NaN
# 291                                 NaN
# 293                                 NaN
# 299                                 NaN
# 301                                 NaN
# 295                                 NaN
# 297                                 NaN
# 225                                 NaN
# 322                                 NaN
# 501                                 NaN
# 502                                 NaN
# 428                                 NaN
# 461                                33.3
# 463                                33.3
# 465                                33.3
# 467                                33.3
# 469                                33.3
# 471                                33.3
# 558                                 NaN
# 713                                 NaN
# 714                                 NaN
# 649                                 NaN
# 818                                 NaN
#
#      odds_aspect_missive_embellishment_hsv2  \
# 118                                     NaN
# 215                                     NaN
# 216                                     NaN
# 291                                     NaN
# 293                                     NaN
# 299                                     NaN
# 301                                     NaN
# 295                                     NaN
# 297                                     NaN
# 225                                     NaN
# 322                                     NaN
# 501                                     NaN
# 502                                     NaN
# 428                                     NaN
# 461                                    33.3
# 463                                    33.3
# 465                                    33.3
# 467                                    33.3
# 469                                    33.3
# 471                                    33.3
# 558                                     NaN
# 713                                     NaN
# 714                                     NaN
# 649                                     NaN
# 818                                     NaN
#
#      odds_aspect_missive_embellishment3 odds_aspect_missive_embellishment_hsv3
# 118                                 NaN                                    NaN
# 215                                 NaN                                    NaN
# 216                                 NaN                                    NaN
# 291                                 NaN                                    NaN
# 293                                 NaN                                    NaN
# 299                                 NaN                                    NaN
# 301                                 NaN                                    NaN
# 295                                 NaN                                    NaN
# 297                                 NaN                                    NaN
# 225                                 NaN                                    NaN
# 322                                 NaN                                    NaN
# 501                                 NaN                                    NaN
# 502                                 NaN                                    NaN
# 428                                 NaN                                    NaN
# 461                               100.0                                  100.0
# 463                               100.0                                  100.0
# 465                               100.0                                  100.0
# 467                               100.0                                  100.0
# 469                               100.0                                  100.0
# 471                               100.0                                  100.0
# 558                                 NaN                                    NaN
# 713                                 NaN                                    NaN
# 714                                 NaN                                    NaN
# 649                                 NaN                                    NaN
# 818                                 NaN                                    NaN
#
# [25 rows x 189 columns]
